# %% [markdown]
# # <b><font color= 'red'> COMP-340 – Final Year Project</font></b>
#
# ## <b>Andreas Neocleous<b>
#
# #### Chirstmas - Easter Prices Comparison

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
newdata = pd.read_csv('../Data/FinalData/EditedFinal.csv')
newdf = pd.DataFrame(newdata)
newdf
# Out:
#           type                                            product  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...        ...                                                ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 0                   NaN      1.00  6.89  3.89  5.62      4  2022
# ...

# %%
xmasComparison= newdata[(newdata['file'] == 'ΠαρατηρητήτιοΤιμώνΧριστουγέννων')]
xmasComparison
# Out:
#        type                                 product  \
# 3146  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3147  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3148  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3149  ΚΡΕΑΣ      χοιρινή μπριζόλα φιλέτο (καρέ) /kg
# 3150  ΚΡΕΑΣ               χοιρινή μπριζόλα λαπά /kg
# ...     ...                                     ...
# 3310  ΧΟΡΤΑ                            χόρτα δέσμης
# 3311  ΧΟΡΤΑ                    πατάτες φρέσκες (kg)
# 3312  ΧΟΡΤΑ                         ντομάτες α (kg)
# 3313  ΧΟΡΤΑ             αγγουράκια θερμοκηπίου (kg)
# 3314  ΧΟΡΤΑ                αγγουράκια χωραφιού (kg)
#
#                          normalized_product  quantity    max   min   avg  \
# 3146           αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  5.95  8.31
# 3147  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.45  5.95  7.91
# 3148         χοιρινός λαπάς με κόκκαλο (kg)       1.0    NaN   NaN   NaN
# ...

# %%
easterComparison= newdata[(newdata['file'] == 'ΠαρατηρητήτιοΤιμώνΠάσχα')]
easterComparison
# Out:
#           type                                            product  \
# 3315     ΚΡΕΑΣ                        αμνοερίφια μικρά ντόπια 1kg
# 3316     ΚΡΕΑΣ               αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3317     ΚΡΕΑΣ                      χοιρινός λαπάς με κόκκαλο 1kg
# 3318     ΚΡΕΑΣ                       χοιρινή μπριζόλα φιλλέτο 1kg
# 3319     ΚΡΕΑΣ                      χοιρινός κιμάς 1kg (από μερί)
# ...        ...                                                ...
# 3382     ΚΡΕΑΣ           κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3383     ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
# 3384     ΚΡΕΑΣ               κουνέλι ντόπιο 1kg (χαμηλότερη τιμή)
# 3385  ΦΛΑΟΥΝΕΣ                               φλαούνες αλμυρές /kg
# 3386  ΦΛΑΟΥΝΕΣ                         φλαούνες με σταφιδάκια /kg
#
#                          normalized_product  quantity    max   min    avg  \
# 3315           αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  5.75   8.32
# ...

# %% [markdown]
# #### Κοτόπουλο Φιλέτο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'κοτόπουλο φιλέτο (kg)')]
temp
# Out:
#        type               product     normalized_product  quantity    max  \
# 3158  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  10.75
# 3178  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  10.30
# 3203  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  10.30
# 3228  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  10.30
# 3253  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  10.30
# 3276  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  10.39
# 3300  ΚΡΕΑΣ  κοτόπουλο φιλέτο /kg  κοτόπουλο φιλέτο (kg)       1.0  12.45
#
#        min   avg  month  year                             file
# 3158  5.49  8.30     12  2016  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3178  5.49  7.91     12  2017  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3203  5.20  7.83     12  2018  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3228  4.50  7.78     12  2019  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'κοτόπουλο φιλέτο (kg)')]
temp1
# Out:
#        type                                            product  \
# 3323  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3335  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3347  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3359  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3371  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
# 3383  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
#
#          normalized_product  quantity    max   min   avg  month  year  \
# 3323  κοτόπουλο φιλέτο (kg)       1.0  10.95  5.49  8.33      4  2016
# 3335  κοτόπουλο φιλέτο (kg)       1.0  10.50  5.75  8.14      4  2017
# 3347  κοτόπουλο φιλέτο (kg)       1.0  10.30  5.60  7.87      4  2019
# 3359  κοτόπουλο φιλέτο (kg)       1.0  10.30  5.95  7.98      4  2020
# 3371  κοτόπουλο φιλέτο (kg)       1.0  10.50  4.99  7.63      4  2021
# 3383  κοτόπουλο φιλέτο (kg)       1.0  10.40  5.99  8.41      4  2022
#
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                                            product  \
# 3158  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3178  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3203  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3228  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3253  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3276  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3300  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3323  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3335  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3347  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3359  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλότερη ...
# 3371  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
# 3383  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
#
#          normalized_product  quantity    max   min   avg  month  year  \
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Κοτόπουλο Ολόκληρο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'κοτόπουλο ολόκληρο (kg)')]
temp
# Out:
#        type                 product       normalized_product  quantity   max  \
# 3157  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  5.00
# 3177  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  5.00
# 3202  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  5.50
# 3227  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  5.50
# 3252  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  5.50
# 3275  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  6.20
# 3299  ΚΡΕΑΣ  κοτόπουλο ολόκληρο /kg  κοτόπουλο ολόκληρο (kg)       1.0  6.65
#
#        min   avg  month  year                             file
# 3157  2.40  3.79     12  2016  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3177  2.49  3.65     12  2017  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3202  2.45  3.67     12  2018  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3227  2.00  3.73     12  2019  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'κοτόπουλο ολόκληρο (kg)')]
temp1
# Out:
#        type                                   product  \
# 3322  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3334  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3346  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3358  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3370  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3382  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
#
#            normalized_product  quantity  max   min   avg  month  year  \
# 3322  κοτόπουλο ολόκληρο (kg)       1.0  5.0  2.65  3.75      4  2016
# 3334  κοτόπουλο ολόκληρο (kg)       1.0  5.5  1.95  3.72      4  2017
# 3346  κοτόπουλο ολόκληρο (kg)       1.0  5.5  2.49  3.66      4  2019
# 3358  κοτόπουλο ολόκληρο (kg)       1.0  5.0  2.49  3.79      4  2020
# 3370  κοτόπουλο ολόκληρο (kg)       1.0  5.0  2.49  3.73      4  2021
# 3382  κοτόπουλο ολόκληρο (kg)       1.0  5.2  2.59  4.18      4  2022
#
#                          file
# 3322  ΠαρατηρητήτιοΤιμώνΠάσχα
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 14)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                                   product  \
# 3157  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3177  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3202  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3227  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3252  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3275  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3299  ΚΡΕΑΣ                    κοτόπουλο ολόκληρο /kg
# 3322  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3334  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3346  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3358  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3370  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3382  ΚΡΕΑΣ  κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
#
#            normalized_product  quantity   max   min   avg  month  year  \
# 3157  κοτόπουλο ολόκληρο (kg)       1.0  5.00  2.40  3.79     12  2016
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Χοιρινή Μπριζόλα Φιλέτο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'χοιρινή μπριζόλα φιλέτο (kg)')]
temp
# Out:
#        type                             product            normalized_product  \
# 3149  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3168  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3193  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3218  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3243  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3266  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3290  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
#
#       quantity   max   min   avg  month  year                             file
# 3149       1.0  6.75  4.72  2.99     12  2016  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3168       1.0  8.00  2.99  4.80     12  2017  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3193       1.0  6.03  2.99  4.66     12  2018  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'χοιρινή μπριζόλα φιλέτο (kg)')]
temp1
# Out:
#        type                       product            normalized_product  \
# 3318  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3330  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3342  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3354  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3366  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3378  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
#
#       quantity   max   min   avg  month  year                     file
# 3318       1.0  6.00  2.75  4.53      4  2016  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3330       1.0  6.00  2.89  4.65      4  2017  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3342       1.0  6.00  2.99  4.72      4  2019  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3354       1.0  6.20  3.65  5.05      4  2020  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3366       1.0  6.99  2.95  4.87      4  2021  ΠαρατηρητήτιοΤιμώνΠάσχα
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 14)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                             product            normalized_product  \
# 3149  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3168  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3193  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3218  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3243  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3266  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3290  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3318  ΚΡΕΑΣ        χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3330  ΚΡΕΑΣ        χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3342  ΚΡΕΑΣ        χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# 3354  ΚΡΕΑΣ        χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Βοδινός Κιμάς (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'βοδινός κιμάς (kg)')]
temp
# Out:
#        type                product  normalized_product  quantity    max   min  \
# 3156  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  12.00  5.65
# 3176  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  12.00  5.35
# 3201  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  12.00  4.89
# 3226  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  12.00  4.90
# 3251  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  12.00  5.35
# 3274  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  12.00  3.99
# 3298  ΚΡΕΑΣ  μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)       1.0  13.75  6.17
#
#        avg  month  year                             file
# 3156  8.05     12  2016  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3176  8.02     12  2017  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3201  8.03     12  2018  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3226  8.06     12  2019  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3251  8.09     12  2020  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'βοδινός κιμάς (kg)')]
temp1
# Out:
#        type                                      product  normalized_product  \
# 3321  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3333  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3345  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3357  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3369  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3381  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
#
#       quantity   max   min   avg  month  year                     file
# 3321       1.0  12.0  3.49  8.03      4  2016  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3333       1.0  12.0  5.25  7.89      4  2017  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3345       1.0  12.0  4.90  8.11      4  2019  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3357       1.0  12.0  4.85  8.07      4  2020  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3369       1.0  12.0  5.75  8.31      4  2021  ΠαρατηρητήτιοΤιμώνΠάσχα
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 14)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                                      product  normalized_product  \
# 3156  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3176  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3201  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3226  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3251  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3274  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3298  ΚΡΕΑΣ                        μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
# 3321  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3333  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3345  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3357  ΚΡΕΑΣ  βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Χοιρινός Λαπάς Με Κόκκαλο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'χοιρινός λαπάς με κόκκαλο (kg)')]
temp
# Out:
#        type                                 product  \
# 3148  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3167  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3192  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3217  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3242  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3265  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3289  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
#
#                   normalized_product  quantity   max   min   avg  month  year  \
# 3148  χοιρινός λαπάς με κόκκαλο (kg)       1.0   NaN   NaN   NaN     12  2016
# 3167  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.00  3.35  4.99     12  2017
# 3192  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.00  3.39  4.90     12  2018
# 3217  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.00  3.99  5.14     12  2019
# 3242  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.25  2.99  4.85     12  2020
# 3265  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.25  3.49  5.08     12  2021
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'χοιρινός λαπάς με κόκκαλο (kg)')]
temp1
# Out:
#        type                        product              normalized_product  \
# 3317  ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
# 3329  ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
# 3341  ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
# 3353  ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
# 3365  ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
# 3377  ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
#
#       quantity   max   min   avg  month  year                     file
# 3317       1.0  6.00  3.39  4.81      4  2016  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3329       1.0  6.00  3.29  4.87      4  2017  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3341       1.0  6.90  2.40  4.96      4  2019  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3353       1.0  6.25  3.89  5.25      4  2020  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3365       1.0  6.25  3.50  5.04      4  2021  ΠαρατηρητήτιοΤιμώνΠάσχα
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 14)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                                 product  \
# 3148  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3167  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3192  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3217  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3242  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3265  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3289  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3317  ΚΡΕΑΣ           χοιρινός λαπάς με κόκκαλο 1kg
# 3329  ΚΡΕΑΣ           χοιρινός λαπάς με κόκκαλο 1kg
# 3341  ΚΡΕΑΣ           χοιρινός λαπάς με κόκκαλο 1kg
# 3353  ΚΡΕΑΣ           χοιρινός λαπάς με κόκκαλο 1kg
# 3365  ΚΡΕΑΣ           χοιρινός λαπάς με κόκκαλο 1kg
# 3377  ΚΡΕΑΣ           χοιρινός λαπάς με κόκκαλο 1kg
#
#                   normalized_product  quantity   max   min   avg  month  year  \
# 3148  χοιρινός λαπάς με κόκκαλο (kg)       1.0   NaN   NaN   NaN     12  2016
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Αμνοερίφια Μικρά Ντόπια (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'αμνοερίφια μικρά ντόπια (kg)')]
temp
# Out:
#        type                                 product  \
# 3146  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3163  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3188  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3213  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3238  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3263  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3285  ΚΡΕΑΣ  αμνοερίφια (μικρά) κομμάτια ντόπια /kg
#
#                 normalized_product  quantity    max   min    avg  month  year  \
# 3146  αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  5.95   8.31     12  2016
# 3163  αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  6.30   8.19     12  2017
# 3188  αμνοερίφια μικρά ντόπια (kg)       1.0   9.50  5.67   7.89     12  2018
# 3213  αμνοερίφια μικρά ντόπια (kg)       1.0  11.25  6.99   8.89     12  2019
# 3238  αμνοερίφια μικρά ντόπια (kg)       1.0  10.45  6.95   8.56     12  2020
# 3263  αμνοερίφια μικρά ντόπια (kg)       1.0  10.60  6.69   8.82     12  2021
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'αμνοερίφια μικρά ντόπια (kg)')]
temp1
# Out:
#        type                      product            normalized_product  \
# 3315  ΚΡΕΑΣ  αμνοερίφια μικρά ντόπια 1kg  αμνοερίφια μικρά ντόπια (kg)
# 3327  ΚΡΕΑΣ  αμνοερίφια μικρά ντόπια 1kg  αμνοερίφια μικρά ντόπια (kg)
# 3339  ΚΡΕΑΣ  αμνοερίφια μικρά ντόπια 1kg  αμνοερίφια μικρά ντόπια (kg)
# 3351  ΚΡΕΑΣ  αμνοερίφια μικρά ντόπια 1kg  αμνοερίφια μικρά ντόπια (kg)
# 3363  ΚΡΕΑΣ  αμνοερίφια μικρά ντόπια 1kg  αμνοερίφια μικρά ντόπια (kg)
# 3375  ΚΡΕΑΣ  αμνοερίφια μικρά ντόπια 1kg  αμνοερίφια μικρά ντόπια (kg)
#
#       quantity    max   min   avg  month  year                     file
# 3315       1.0  10.00  5.75  8.32      4  2016  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3327       1.0  10.00  5.29  7.76      4  2017  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3339       1.0   9.50  5.69  7.67      4  2019  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3351       1.0  10.00  5.69  8.21      4  2020  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3363       1.0  10.45  6.49  8.50      4  2021  ΠαρατηρητήτιοΤιμώνΠάσχα
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 14)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                                 product  \
# 3146  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3163  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3188  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3213  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3238  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3263  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3285  ΚΡΕΑΣ  αμνοερίφια (μικρά) κομμάτια ντόπια /kg
# 3315  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια 1kg
# 3327  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια 1kg
# 3339  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια 1kg
# 3351  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια 1kg
# 3363  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια 1kg
# 3375  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια 1kg
#
#                 normalized_product  quantity    max   min    avg  month  year  \
# 3146  αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  5.95   8.31     12  2016
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Αμνοερίφια Μικρά Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Αμνοερίφια Μικρά Ολόκληρα Ντόπια (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'αμνοερίφια μικρά ολόκληρα ντόπια (kg)')]
temp
# Out:
#        type                                 product  \
# 3147  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3165  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3190  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3215  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3240  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3264  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3287  ΚΡΕΑΣ  αμνοερίφια (μικρά) ολόκληρα ντόπια /kg
#
#                          normalized_product  quantity    max   min    avg  \
# 3147  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.45  5.95   7.91
# 3165  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.00  6.30   7.70
# 3190  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.00  5.67   7.46
# 3215  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  11.25  6.50   8.39
# 3240  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.00  6.95   8.10
# 3264  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.00  6.69   8.32
# ...

# %%
temp1 = easterComparison[(easterComparison['normalized_product'] == 'αμνοερίφια μικρά ολόκληρα ντόπια (kg)')]
temp1
# Out:
#        type                               product  \
# 3316  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3328  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3340  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3352  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3364  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3376  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
#
#                          normalized_product  quantity    max   min   avg  \
# 3316  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.45  5.75  7.82
# 3328  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.50  5.29  7.33
# 3340  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   8.90  5.69  7.19
# 3352  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.75  5.69  7.77
# 3364  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.80  6.39  8.03
# 3376  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.00  6.99  8.55
#
#       month  year                     file
# 3316      4  2016  ΠαρατηρητήτιοΤιμώνΠάσχα
# ...

# %%
ax = temp.plot(x='year', y='min', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='min', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ολόκληρα Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Ελάχιστη Τιμή')

# %%
ax = temp.plot(x='year', y='max', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='max', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ολόκληρα Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέγιστη Τιμή')

# %%
ax = temp.plot(x='year', y='avg', marker='.', color = 'r', label='Χριστούγεννα')
temp1.plot(ax=ax, x='year', y='avg', marker='.', color = 'gold', label='Πάσχα')
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ολόκληρα Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 14)
plt.ylabel('Μέση Σταθμισμένη Τιμή', color = 'C0', labelpad = 20, fontsize = 14)
# Out:
# Text(0, 0.5, 'Μέση Σταθμισμένη Τιμή')

# %%
cf = pd.concat([temp,temp1], axis = 0)
cf
# Out:
#        type                                 product  \
# 3147  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3165  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3190  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3215  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3240  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3264  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3287  ΚΡΕΑΣ  αμνοερίφια (μικρά) ολόκληρα ντόπια /kg
# 3316  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3328  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3340  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3352  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3364  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3376  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια 1kg
#
#                          normalized_product  quantity    max   min    avg  \
# 3147  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.45  5.95   7.91
# 3165  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.00  6.30   7.70
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
my_pal = {"ΠαρατηρητήτιοΤιμώνΧριστουγέννων": "r", "ΠαρατηρητήτιοΤιμώνΠάσχα": "gold"}
plt.suptitle('Σύγκριση Τιμών: Πάσχα - Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Αμνοερίφια Μικρά Ολόκληρα Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='min',palette= my_pal, ax=axes[0])
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='max',palette= my_pal, ax=axes[1])
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Αμνοερίφια Μικρά Ολόκληρα Ντόπια (kg)', color = 'C0', labelpad = 20, fontsize = 12)

sns.boxplot(data=cf, x='file',y='avg',palette= my_pal, ax=axes[2])
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Christmas Time

# %%
xmas = newdf[(newdf['file'] == 'ΠαρατηρητήτιοΤιμώνΧριστουγέννων')]
xmas
# Out:
#        type                                 product  \
# 3146  ΚΡΕΑΣ             αμνοερίφια μικρά ντόπια /kg
# 3147  ΚΡΕΑΣ    αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3148  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3149  ΚΡΕΑΣ      χοιρινή μπριζόλα φιλέτο (καρέ) /kg
# 3150  ΚΡΕΑΣ               χοιρινή μπριζόλα λαπά /kg
# ...     ...                                     ...
# 3310  ΧΟΡΤΑ                            χόρτα δέσμης
# 3311  ΧΟΡΤΑ                    πατάτες φρέσκες (kg)
# 3312  ΧΟΡΤΑ                         ντομάτες α (kg)
# 3313  ΧΟΡΤΑ             αγγουράκια θερμοκηπίου (kg)
# 3314  ΧΟΡΤΑ                αγγουράκια χωραφιού (kg)
#
#                          normalized_product  quantity    max   min   avg  \
# 3146           αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  5.95  8.31
# 3147  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0   9.45  5.95  7.91
# 3148         χοιρινός λαπάς με κόκκαλο (kg)       1.0    NaN   NaN   NaN
# ...

# %%
temps = []
temps.append(xmas[xmas['normalized_product'] == 'γαλοπούλα ντόπια (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'γαλοπούλα εισαγόμενη (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες αμυγδάλου (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'christmas cake (kg)'])

# %%
ax = temps[0].plot(x='year', y='avg', marker='.', label='Γαλοπούλα Ντόπια')
temps[1].plot(ax=ax, x='year', y='avg', marker='.', label='Γαλοπούλα εισαγόμενη')
temps[2].plot(ax=ax, x='year', y='avg', marker='.', label='Μελομακάρονα')
temps[3].plot(ax=ax, x='year', y='avg', marker='.', label='Κουραμπιέδες')
temps[4].plot(ax=ax, x='year', y='avg', marker='.', label='Christmas Cake')
plt.suptitle('Σύγκριση Τιμών: Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Εποχιακά προϊόντα (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %%
temps.clear()
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα επικαλυμμένα με σοκολάτα (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα συσκευασμένα 500g'])

# %%
ax = temps[0].plot(x='year', y='avg', marker='.', label='Μελομακάρονα')
temps[1].plot(ax=ax, x='year', y='avg', marker='.', label='Μελομακάρονα επικαλυμμένα με σοκολάτα')
temps[2].plot(ax=ax, x='year', y='avg', marker='.', label='Μελομακάρονα συσκευασμένα 500g')
plt.suptitle('Σύγκριση Τιμών: Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Εποχιακά προϊόντα (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %%
temps.clear()
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα επικαλυμμένα με σοκολάτα (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'μελομακάρονα συσκευασμένα 500g'])

# %%
# ekamame ta 500g se kg
temps[2]['avg'] = temps[2]['avg'] * 2
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_15056\643482665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps[2]['avg'] = temps[2]['avg'] * 2

# %%
ax = temps[0].plot(x='year', y='avg', marker='.', label='Μελομακάρονα')
temps[1].plot(ax=ax, x='year', y='avg', marker='.', label='Μελομακάρονα επικαλυμμένα με σοκολάτα')
temps[2].plot(ax=ax, x='year', y='avg', marker='.', label='Μελομακάρονα συσκευασμένα (kg)')
plt.suptitle('Σύγκριση Τιμών: Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Εποχιακά προϊόντα (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %%
temps.clear()
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες αμυγδάλου (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες συσκευασμένοι 500g'])

# %%
ax = temps[0].plot(x='year', y='avg', marker='.', label='Κουραμπιέδες Αμυγδάλου')
temps[1].plot(ax=ax, x='year', y='avg', marker='.', label='Κουραμπιέδες με Γέμιση Φοινίκι (Φοινικωτά)')
temps[2].plot(ax=ax, x='year', y='avg', marker='.', label='Κουραμπιέδες Συσκευασμένοι 500g')
plt.suptitle('Σύγκριση Τιμών: Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Εποχιακά προϊόντα (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %%
temps.clear()
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες αμυγδάλου (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) (kg)'])
temps.append(xmas[xmas['normalized_product'] == 'κουραμπιέδες συσκευασμένοι 500g'])

# %%
# ekamame ta 500g se kg
temps[2]['avg'] = temps[2]['avg'] * 2
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_15056\643482665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temps[2]['avg'] = temps[2]['avg'] * 2

# %%
ax = temps[0].plot(x='year', y='avg', marker='.', label='Κουραμπιέδες Αμυγδάλου')
temps[1].plot(ax=ax, x='year', y='avg', marker='.', label='Κουραμπιέδες με Γέμιση Φοινίκι (Φοινικωτά)')
temps[2].plot(ax=ax, x='year', y='avg', marker='.', label='Κουραμπιέδες Συσκευασμένοι (kg))')
plt.suptitle('Σύγκριση Τιμών: Χριστούγεννα', color = 'C3', fontsize = 16)
plt.xlabel('Εποχιακά προϊόντα (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Easter Time

# %%
easter = newdf[(newdf['file'] == 'ΠαρατηρητήτιοΤιμώνΠάσχα')]
easter
# Out:
#           type                                            product  \
# 3315     ΚΡΕΑΣ                        αμνοερίφια μικρά ντόπια 1kg
# 3316     ΚΡΕΑΣ               αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3317     ΚΡΕΑΣ                      χοιρινός λαπάς με κόκκαλο 1kg
# 3318     ΚΡΕΑΣ                       χοιρινή μπριζόλα φιλλέτο 1kg
# 3319     ΚΡΕΑΣ                      χοιρινός κιμάς 1kg (από μερί)
# ...        ...                                                ...
# 3382     ΚΡΕΑΣ           κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3383     ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
# 3384     ΚΡΕΑΣ               κουνέλι ντόπιο 1kg (χαμηλότερη τιμή)
# 3385  ΦΛΑΟΥΝΕΣ                               φλαούνες αλμυρές /kg
# 3386  ΦΛΑΟΥΝΕΣ                         φλαούνες με σταφιδάκια /kg
#
#                          normalized_product  quantity    max   min    avg  \
# 3315           αμνοερίφια μικρά ντόπια (kg)       1.0  10.00  5.75   8.32
# ...

# %%
temps = []
temps.append(easter[easter['normalized_product'] == 'φλαούνες αλμυρές (kg)'])
temps.append(easter[easter['normalized_product'] == 'φλαούνες με σταφιδάκια (kg)'])

# %%
ax = temps[0].plot(x='year', y='avg', marker='.', label='Φλαούνες αλμυρές')
temps[1].plot(ax=ax, x='year', y='avg', marker='.', label='Φλαούνες με σταφιδάκια')
plt.suptitle('Σύγκριση Τιμών: Πάσχα', color = 'C3', fontsize = 16)
plt.xlabel('Εποχιακά προϊόντα (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')
