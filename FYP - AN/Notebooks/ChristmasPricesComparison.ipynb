# %% [markdown]
# # <b><font color= 'red'> COMP494,495 – Final Year Project</font></b>
#
# ## <b>Andreas Neocleous<b>
#
# #### Chirstmas Prices Comparison

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
newdata = pd.read_csv('../Data/FinalData/EditedFinal.csv')
newdf = pd.DataFrame(newdata)
newdf
# Out:
#           type                                            product  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...        ...                                                ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 0                   NaN      1.00  6.89  3.89  5.62      4  2022
# 1                   NaN      1.00  2.82  1.77  2.12      4  2022
# 2                   NaN      1.00  4.07  2.75  3.48      4  2022
# 3                   NaN      1.00  4.59  2.65  3.24      4  2022
# 4                   NaN      1.00  2.69  1.35  1.84      4  2022
# ...                 ...       ...   ...   ...   ...    ...   ...
# 3580                NaN      1.00  2.40  1.10  1.75      3  2022
# 3581                NaN      0.75  4.50  2.35  3.08      3  2022
# 3582                NaN      0.75  5.20  2.35  3.68      3  2022
# 3583                NaN      5.00  5.50  3.99  4.69      3  2022
# 3584                NaN      5.00  5.28  3.99  4.50      3  2022
#
#                                    file
# 0               ΒασικάΚαταναλωτικάΑγαθά
# 1               ΒασικάΚαταναλωτικάΑγαθά
# 2               ΒασικάΚαταναλωτικάΑγαθά
# 3               ΒασικάΚαταναλωτικάΑγαθά
# 4               ΒασικάΚαταναλωτικάΑγαθά
# ...                                 ...
# 3580  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3581  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3582  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3583  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3584  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
#
# [3585 rows x 10 columns]

# %% [markdown]
# ### 2022

# %%
xmasComparison= newdata[(newdata['month'] == 12) & (newdata['year'] == 2022) & (newdata['type'] == 'ΚΡΕΑΣ')]
xmasComparison
# Out:
#        type                                            product  \
# 632   ΚΡΕΑΣ                     χοιρινός λαπάς με κόκκαλο (kg)
# 633   ΚΡΕΑΣ                       χοιρινή μπριζόλα φιλέτο (kg)
# 634   ΚΡΕΑΣ                     χοιρινός κιμάς (από μερί) (kg)
# 635   ΚΡΕΑΣ          κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 636   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 637   ΚΡΕΑΣ                              αμνοερίφια μικρά (kg)
# 638   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 639   ΚΡΕΑΣ       βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)
# 640   ΚΡΕΑΣ                     κουνέλι (kg) (χαμηλότερη τιμή)
# 3285  ΚΡΕΑΣ             αμνοερίφια (μικρά) κομμάτια ντόπια /kg
# 3286  ΚΡΕΑΣ         αμνοερίφια (μικρά) κομμάτια εισαγόμενα /kg
# 3287  ΚΡΕΑΣ             αμνοερίφια (μικρά) ολόκληρα ντόπια /kg
# 3288  ΚΡΕΑΣ         αμνοερίφια (μικρά) ολόκληρα εισαγόμενα /kg
# 3289  ΚΡΕΑΣ             χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3290  ΚΡΕΑΣ                 χοιρινή μπριζόλα φιλέτο (καρέ) /kg
# 3291  ΚΡΕΑΣ                          χοιρινή μπριζόλα λαπά /kg
# 3292  ΚΡΕΑΣ  χοιρινός κιμάς (καθαρός - ψαχνό χωρίς λίπος ) /kg
# 3293  ΚΡΕΑΣ                         χοιρινός κιμάς κουτάλα /kg
# 3294  ΚΡΕΑΣ                        χοιρινό μερί με κόκκαλο /kg
# 3295  ΚΡΕΑΣ                     χοιρινή κουτάλα με κόκκαλο /kg
# 3296  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3297  ΚΡΕΑΣ                  μοσχαρίσια μπριζόλα (ντόπια ) /kg
# 3298  ΚΡΕΑΣ                              μοσχαρίσιος κιμάς /kg
# 3299  ΚΡΕΑΣ                             κοτόπουλο ολόκληρο /kg
# 3300  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3301  ΚΡΕΑΣ                               γαλοπούλα ντόπια /kg
# 3302  ΚΡΕΑΣ                           γαλοπούλα εισαγόμενη /kg
#
#                          normalized_product  quantity    max   min    avg  \
# 632          χοιρινός λαπάς με κόκκαλο (kg)       1.0   6.75  4.49   5.43
# 633            χοιρινή μπριζόλα φιλέτο (kg)       1.0   7.58  4.35   5.31
# 634                                     NaN       1.0   7.25  3.99   5.30
# 635                 κοτόπουλο ολόκληρο (kg)       1.0   4.50  2.99   3.75
# 636                   κοτόπουλο φιλέτο (kg)       1.0   9.99  6.49   7.84
# 637                                     NaN       1.0  12.90  7.95   9.63
# 638                    βοδινό top-side (kg)       1.0  15.99  7.99  12.11
# 639                      βοδινός κιμάς (kg)       1.0  12.95  6.17   8.46
# 640                                     NaN       1.0  10.49  8.50   9.69
# 3285           αμνοερίφια μικρά ντόπια (kg)       1.0  14.00  8.15  10.95
# 3286                                    NaN       1.0  11.90  8.50   9.83
# 3287  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  13.50  7.95  10.31
# 3288                                    NaN       1.0  11.40  6.30   9.38
# 3289         χοιρινός λαπάς με κόκκαλο (kg)       1.0   6.95  4.55   5.89
# 3290           χοιρινή μπριζόλα φιλέτο (kg)       1.0   7.05  4.45   5.69
# 3291                                    NaN       1.0   6.95  4.45   5.89
# 3292                                    NaN       1.0   8.00  3.89   6.16
# 3293                                    NaN       1.0   7.50  3.49   5.44
# 3294                                    NaN       1.0   6.50  3.35   4.99
# 3295                                    NaN       1.0   6.50  3.35   4.87
# 3296            βοδινό top-side ντόπιο (kg)       1.0  16.85  7.99  12.10
# 3297                                    NaN       1.0  29.85  6.75   9.78
# 3298                     βοδινός κιμάς (kg)       1.0  13.75  6.17   9.56
# 3299                κοτόπουλο ολόκληρο (kg)       1.0   6.65  2.99   4.22
# 3300                  κοτόπουλο φιλέτο (kg)       1.0  12.45  5.95   8.57
# 3301                  γαλοπούλα ντόπια (kg)       1.0   8.05  4.90   6.34
# 3302              γαλοπούλα εισαγόμενη (kg)       1.0   6.95  4.60   4.87
#
#       month  year                             file
# 632      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 633      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 634      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 635      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 636      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 637      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 638      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 639      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 640      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 3285     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3286     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3287     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3288     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3289     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3290     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3291     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3292     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3293     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3294     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3295     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3296     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3297     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3298     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3299     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3300     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3301     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3302     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %% [markdown]
# #### Κοτόπουλο Φιλέτο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'κοτόπουλο φιλέτο (kg)')]
temp
# Out:
#        type                                         product  \
# 636   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 3300  ΚΡΕΑΣ                            κοτόπουλο φιλέτο /kg
#
#          normalized_product  quantity    max   min   avg  month  year  \
# 636   κοτόπουλο φιλέτο (kg)       1.0   9.99  6.49  7.84     12  2022
# 3300  κοτόπουλο φιλέτο (kg)       1.0  12.45  5.95  8.57     12  2022
#
#                                  file
# 636           ΒασικάΚαταναλωτικάΑγαθά
# 3300  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Κοτόπουλο Ολόκληρο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'κοτόπουλο ολόκληρο (kg)')]
temp
# Out:
#        type                                    product  \
# 635   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 3299  ΚΡΕΑΣ                     κοτόπουλο ολόκληρο /kg
#
#            normalized_product  quantity   max   min   avg  month  year  \
# 635   κοτόπουλο ολόκληρο (kg)       1.0  4.50  2.99  3.75     12  2022
# 3299  κοτόπουλο ολόκληρο (kg)       1.0  6.65  2.99  4.22     12  2022
#
#                                  file
# 635           ΒασικάΚαταναλωτικάΑγαθά
# 3299  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινή Μπριζόλα Φιλέτο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'χοιρινή μπριζόλα φιλέτο (kg)')]
temp
# Out:
#        type                             product            normalized_product  \
# 633   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 3290  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
#
#       quantity   max   min   avg  month  year                             file
# 633        1.0  7.58  4.35  5.31     12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 3290       1.0  7.05  4.45  5.69     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Βοδινός Κιμάς (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'βοδινός κιμάς (kg)')]
temp
# Out:
#        type                                       product  normalized_product  \
# 639   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3298  ΚΡΕΑΣ                         μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
#
#       quantity    max   min   avg  month  year  \
# 639        1.0  12.95  6.17  8.46     12  2022
# 3298       1.0  13.75  6.17  9.56     12  2022
#
#                                  file
# 639           ΒασικάΚαταναλωτικάΑγαθά
# 3298  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινός Λαπάς Με Κόκκαλο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'χοιρινός λαπάς με κόκκαλο (kg)')]
temp
# Out:
#        type                                 product  \
# 632   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 3289  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
#
#                   normalized_product  quantity   max   min   avg  month  year  \
# 632   χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.75  4.49  5.43     12  2022
# 3289  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.95  4.55  5.89     12  2022
#
#                                  file
# 632           ΒασικάΚαταναλωτικάΑγαθά
# 3289  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Αμνοερίφια

# %%
xmasComparison[(xmasComparison['product'].str.find('αμν')!= -1)]
# Out:
#        type                                     product  \
# 637   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 3285  ΚΡΕΑΣ      αμνοερίφια (μικρά) κομμάτια ντόπια /kg
# 3286  ΚΡΕΑΣ  αμνοερίφια (μικρά) κομμάτια εισαγόμενα /kg
# 3287  ΚΡΕΑΣ      αμνοερίφια (μικρά) ολόκληρα ντόπια /kg
# 3288  ΚΡΕΑΣ  αμνοερίφια (μικρά) ολόκληρα εισαγόμενα /kg
#
#                          normalized_product  quantity   max   min    avg  \
# 637                                     NaN       1.0  12.9  7.95   9.63
# 3285           αμνοερίφια μικρά ντόπια (kg)       1.0  14.0  8.15  10.95
# 3286                                    NaN       1.0  11.9  8.50   9.83
# 3287  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  13.5  7.95  10.31
# 3288                                    NaN       1.0  11.4  6.30   9.38
#
#       month  year                             file
# 637      12  2022          ΒασικάΚαταναλωτικάΑγαθά
# 3285     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3286     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3287     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3288     12  2022  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %% [markdown]
# Για το συγκεκριμένο προϊόν δεν υπάρχει κοινή περιγραφή, ως εκ τουτου δεν θα προχωρίσουμε σε σύγκριση τιμών και γραφική αναπαράσταση

# %% [markdown]
# ### 2021

# %%
xmasComparison= newdata[(newdata['month'] == 12) & (newdata['year'] == 2021) & (newdata['type'] == 'ΚΡΕΑΣ')]
xmasComparison
# Out:
#        type                                            product  \
# 465   ΚΡΕΑΣ                     χοιρινός λαπάς με κόκκαλο (kg)
# 466   ΚΡΕΑΣ                       χοιρινή μπριζόλα φιλέτο (kg)
# 467   ΚΡΕΑΣ                     χοιρινός κιμάς (από μερί) (kg)
# 468   ΚΡΕΑΣ          κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 469   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 470   ΚΡΕΑΣ                              αμνοερίφια μικρά (kg)
# 471   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 472   ΚΡΕΑΣ       βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)
# 473   ΚΡΕΑΣ                     κουνέλι (kg) (χαμηλότερη τιμή)
# 3263  ΚΡΕΑΣ                        αμνοερίφια μικρά ντόπια /kg
# 3264  ΚΡΕΑΣ               αμνοερίφια μικρά ολόκληρα ντόπια /kg
# 3265  ΚΡΕΑΣ             χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
# 3266  ΚΡΕΑΣ                 χοιρινή μπριζόλα φιλέτο (καρέ) /kg
# 3267  ΚΡΕΑΣ                          χοιρινή μπριζόλα λαπά /kg
# 3268  ΚΡΕΑΣ  χοιρινός κιμάς (καθαρός - ψαχνό χωρίς λίπος ) /kg
# 3269  ΚΡΕΑΣ                         χοιρινός κιμάς κουτάλα /kg
# 3270  ΚΡΕΑΣ                        χοιρινό μερί με κόκκαλο /kg
# 3271  ΚΡΕΑΣ                     χοιρινή κουτάλα με κόκκαλο /kg
# 3272  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3273  ΚΡΕΑΣ                  μοσχαρίσια μπριζόλα (ντόπια ) /kg
# 3274  ΚΡΕΑΣ                              μοσχαρίσιος κιμάς /kg
# 3275  ΚΡΕΑΣ                             κοτόπουλο ολόκληρο /kg
# 3276  ΚΡΕΑΣ                               κοτόπουλο φιλέτο /kg
# 3277  ΚΡΕΑΣ                               γαλοπούλα ντόπια /kg
#
#                          normalized_product  quantity    max   min    avg  \
# 465          χοιρινός λαπάς με κόκκαλο (kg)       1.0   5.50  3.79   4.66
# 466            χοιρινή μπριζόλα φιλέτο (kg)       1.0   5.50  3.65   4.36
# 467                                     NaN       1.0   6.25  2.95   4.33
# 468                 κοτόπουλο ολόκληρο (kg)       1.0   4.25  2.59   3.22
# 469                   κοτόπουλο φιλέτο (kg)       1.0   9.00  5.89   6.78
# 470                                     NaN       1.0  10.00  6.85   8.41
# 471                    βοδινό top-side (kg)       1.0  12.99  6.95   9.99
# 472                      βοδινός κιμάς (kg)       1.0  11.99  5.95   7.49
# 473                                     NaN       1.0   9.75  7.50   8.73
# 3263           αμνοερίφια μικρά ντόπια (kg)       1.0  10.60  6.69   8.82
# 3264  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.00  6.69   8.32
# 3265         χοιρινός λαπάς με κόκκαλο (kg)       1.0   6.25  3.49   5.08
# 3266           χοιρινή μπριζόλα φιλέτο (kg)       1.0   6.25  2.95   4.91
# 3267                                    NaN       1.0   6.25  3.49   5.10
# 3268                                    NaN       1.0   6.95  2.99   5.43
# 3269                                    NaN       1.0   6.40  2.59   4.74
# 3270                                    NaN       1.0   5.90  2.99   4.27
# 3271                                    NaN       1.0   5.85  2.49   4.08
# 3272            βοδινό top-side ντόπιο (kg)       1.0  13.00  6.95  10.02
# 3273                                    NaN       1.0  13.55  5.45   7.89
# 3274                     βοδινός κιμάς (kg)       1.0  12.00  3.99   8.05
# 3275                κοτόπουλο ολόκληρο (kg)       1.0   6.20  2.59   3.85
# 3276                  κοτόπουλο φιλέτο (kg)       1.0  10.39  5.69   7.94
# 3277                  γαλοπούλα ντόπια (kg)       1.0   6.90  4.65   5.52
#
#       month  year                             file
# 465      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 466      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 467      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 468      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 469      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 470      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 471      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 472      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 473      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 3263     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3264     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3265     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3266     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3267     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3268     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3269     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3270     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3271     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3272     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3273     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3274     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3275     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3276     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3277     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %% [markdown]
# #### Κοτόπουλο Φιλέτο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'κοτόπουλο φιλέτο (kg)')]
temp
# Out:
#        type                                         product  \
# 469   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 3276  ΚΡΕΑΣ                            κοτόπουλο φιλέτο /kg
#
#          normalized_product  quantity    max   min   avg  month  year  \
# 469   κοτόπουλο φιλέτο (kg)       1.0   9.00  5.89  6.78     12  2021
# 3276  κοτόπουλο φιλέτο (kg)       1.0  10.39  5.69  7.94     12  2021
#
#                                  file
# 469           ΒασικάΚαταναλωτικάΑγαθά
# 3276  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2021', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Κοτόπουλο Ολόκληρο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'κοτόπουλο ολόκληρο (kg)')]
temp
# Out:
#        type                                    product  \
# 468   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 3275  ΚΡΕΑΣ                     κοτόπουλο ολόκληρο /kg
#
#            normalized_product  quantity   max   min   avg  month  year  \
# 468   κοτόπουλο ολόκληρο (kg)       1.0  4.25  2.59  3.22     12  2021
# 3275  κοτόπουλο ολόκληρο (kg)       1.0  6.20  2.59  3.85     12  2021
#
#                                  file
# 468           ΒασικάΚαταναλωτικάΑγαθά
# 3275  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2021', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινή Μπριζόλα Φιλέτο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'χοιρινή μπριζόλα φιλέτο (kg)')]
temp
# Out:
#        type                             product            normalized_product  \
# 466   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 3266  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (καρέ) /kg  χοιρινή μπριζόλα φιλέτο (kg)
#
#       quantity   max   min   avg  month  year                             file
# 466        1.0  5.50  3.65  4.36     12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 3266       1.0  6.25  2.95  4.91     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2021', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Βοδινός Κιμάς (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'βοδινός κιμάς (kg)')]
temp
# Out:
#        type                                       product  normalized_product  \
# 472   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3274  ΚΡΕΑΣ                         μοσχαρίσιος κιμάς /kg  βοδινός κιμάς (kg)
#
#       quantity    max   min   avg  month  year  \
# 472        1.0  11.99  5.95  7.49     12  2021
# 3274       1.0  12.00  3.99  8.05     12  2021
#
#                                  file
# 472           ΒασικάΚαταναλωτικάΑγαθά
# 3274  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2021', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινός Λαπάς Με Κόκκαλο (kg)

# %%
temp = xmasComparison[(xmasComparison['normalized_product'] == 'χοιρινός λαπάς με κόκκαλο (kg)')]
temp
# Out:
#        type                                 product  \
# 465   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 3265  ΚΡΕΑΣ  χοιρινός (λαιμός) λαπάς με κόκκαλο /kg
#
#                   normalized_product  quantity   max   min   avg  month  year  \
# 465   χοιρινός λαπάς με κόκκαλο (kg)       1.0  5.50  3.79  4.66     12  2021
# 3265  χοιρινός λαπάς με κόκκαλο (kg)       1.0  6.25  3.49  5.08     12  2021
#
#                                  file
# 465           ΒασικάΚαταναλωτικάΑγαθά
# 3265  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Χριστούγεννα 2021', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Αμνοερίφια

# %%
xmasComparison[(xmasComparison['product'].str.find('αμν')!= -1)]
# Out:
#        type                               product  \
# 470   ΚΡΕΑΣ                 αμνοερίφια μικρά (kg)
# 3263  ΚΡΕΑΣ           αμνοερίφια μικρά ντόπια /kg
# 3264  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια /kg
#
#                          normalized_product  quantity   max   min   avg  \
# 470                                     NaN       1.0  10.0  6.85  8.41
# 3263           αμνοερίφια μικρά ντόπια (kg)       1.0  10.6  6.69  8.82
# 3264  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.0  6.69  8.32
#
#       month  year                             file
# 470      12  2021          ΒασικάΚαταναλωτικάΑγαθά
# 3263     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# 3264     12  2021  ΠαρατηρητήτιοΤιμώνΧριστουγέννων

# %% [markdown]
# Για το συγκεκριμένο προϊόν δεν υπάρχει κοινή περιγραφή, ως εκ τουτου δεν θα προχωρίσουμε σε σύγκριση τιμών και γραφική αναπαράσταση
