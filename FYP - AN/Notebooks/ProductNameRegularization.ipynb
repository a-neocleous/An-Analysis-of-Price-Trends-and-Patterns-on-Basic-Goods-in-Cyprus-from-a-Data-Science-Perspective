# %% [markdown]
# # <b><font color= 'red'> COMP494,495 – Final Year Project</font></b>
#
# ## <b>Andreas Neocleous<b>
#
# #### Product Name Regularization

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('../Data/FinalData/Final.xlsx')

df = pd.DataFrame(data)
df = df.drop("Unnamed: 0",axis=1)
df['product'] = df['product'].str.lower()
df
# Out:
#           type                                            product  quantity  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg      1.00
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg      1.00
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...      1.00
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg      1.00
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg      1.00
# ...        ...                                                ...       ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο      1.00
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl      0.75
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl      0.75
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg      5.00
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg      5.00
#
# ...

# %%
str = 'NaN'
normProduct = []
for i in range(len(df)):
   normProduct.append(str)
#df['normalized_product'] = normProduct
df.insert(2, 'normalized_product', normProduct, True)
df
# Out:
#           type                                            product  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...        ...                                                ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 0                   NaN      1.00  6.89  3.89  5.62      4  2022
# ...

# %%
arr = (df['product'].str.find('βοδινός κιμάς')!= -1)|(df['product'].str.find('μοσχαρίσιος κιμάς')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'βοδινός κιμάς (kg)'

# results    
df[(df['product'].str.find('βοδινός κιμάς')!= -1)|(df['product'].str.find('μοσχαρίσιος κιμάς')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2646246099.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'βοδινός κιμάς (kg)'
#        type                                       product  normalized_product  \
# 136   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 304   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 472   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 639   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 807   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1023  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# ...

# %%
arr = (df['product'].str.find('αλαμάρι')!= -1)&(df['product'].str.find('μεγάλο')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'καλαμάρι μεγάλο (kg)'

# results    
df[(df['product'].str.find('αλαμάρι')!= -1)&(df['product'].str.find('μεγάλο')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\586387654.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'καλαμάρι μεγάλο (kg)'
#                       type                      product    normalized_product  \
# 142    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ         καλαμάρι μεγάλο (kg)  καλαμάρι μεγάλο (kg)
# 310    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ         καλαμάρι μεγάλο (kg)  καλαμάρι μεγάλο (kg)
# 478    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ         καλαμάρι μεγάλο (kg)  καλαμάρι μεγάλο (kg)
# 645    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ         καλαμάρι μεγάλο (kg)  καλαμάρι μεγάλο (kg)
# 813   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ         καλαμάρι μεγάλο (kg)  καλαμάρι μεγάλο (kg)
# 1031   ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ         καλαμάρι μεγάλο (kg)  καλαμάρι μεγάλο (kg)
# ...

# %%
arr = (df['product'].str.find('ταπόδι')!= -1)&(df['product'].str.find('μεγάλο')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χταπόδι μεγάλο (kg)'

# results    
df[(df['product'].str.find('ταπόδι')!= -1)&(df['product'].str.find('μεγάλο')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3452307593.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χταπόδι μεγάλο (kg)'
#                       type                      product   normalized_product  \
# 144    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# 312    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# 480    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# 647    ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# 815   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# 1036   ΦΡΕΣΚΟ ΨΑΡΙ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# 1233  ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ          χταπόδι μεγάλο (kg)  χταπόδι μεγάλο (kg)
# ...

# %%
arr = (df['type'].str.find('ΜΑΛΑΚΙΑ')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['type'][i] = 'ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ'

# results    
df[(df['type'].str.find('ΜΑΛΑΚΙΑ')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2282174148.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['type'][i] = 'ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ'
#                       type                                     product  \
# 138   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ                         λαβράκι μεγάλο (kg)
# 139   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ                        τσιπούρα μεγάλη (kg)
# 140   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ                                  γόπες (kg)
# 141   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ                             μπαρμπούνι (kg)
# 142   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ                        καλαμάρι μεγάλο (kg)
# ...                    ...                                         ...
# 3571  ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  edesma ολόκληρες σουπιές καθαρισμένες 800g
# ...

# %%
arr = (df['product'].str.find('κοτόπουλο')!= -1)&(df['product'].str.find('φιλ')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'κοτόπουλο φιλέτο (kg)'

# results    
df[(df['product'].str.find('κοτόπουλο')!= -1)&(df['product'].str.find('φιλ')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2830018876.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'κοτόπουλο φιλέτο (kg)'
#        type                                            product  \
# 133   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 301   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 469   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 636   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 804   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1025  ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1222  ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1402  ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# ...

# %%
arr = (df['product'].str.find('κοτόπουλο')!= -1)&(df['product'].str.find('ολό')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'κοτόπουλο ολόκληρο (kg)'

# results    
df[(df['product'].str.find('κοτόπουλο')!= -1)&(df['product'].str.find('ολό')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3365579642.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'κοτόπουλο ολόκληρο (kg)'
#        type                                    product  \
# 132   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 300   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 468   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 635   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 803   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 1024  ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 1221  ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 1401  ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 1599  ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 1767  ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# ...

# %%
arr = (df['product'].str.find('χοιρινή μπριζόλα φ')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χοιρινή μπριζόλα φιλέτο (kg)'

# results    
df[(df['product'].str.find('χοιρινή μπριζόλα φ')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\615285298.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χοιρινή μπριζόλα φιλέτο (kg)'
#        type                             product            normalized_product  \
# 130   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 298   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 466   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 633   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 801   ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1027  ΚΡΕΑΣ        χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# ...

# %%
arr = (df['product'].str.find('top-side')!= -1)&(df['product'].str.find('ντόπιο')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'βοδινό top-side ντόπιο (kg)'

# results    
df[(df['product'].str.find('top-side')!= -1)&(df['product'].str.find('ντόπιο')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3450326295.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'βοδινό top-side ντόπιο (kg)'
#        type                                            product  \
# 3174  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3199  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3224  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3249  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3272  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3296  ΚΡΕΑΣ       μοσχαρίσιο top-side χωρίς κόκκαλο ντόπιο /kg
# 3320  ΚΡΕΑΣ  βοδινό top-side ντόπιο 1kg (ψαχνό, χωρίς κόκκα...
# 3332  ΚΡΕΑΣ  βοδινό top-side ντόπιο 1kg (ψαχνό, χωρίς κόκκα...
# ...

# %%
arr = (df['product'].str.find('βοδινό top-side (kg)')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'βοδινό top-side (kg)'

# results    
df[(df['product'].str.find('βοδινό top-side (kg)')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1742009840.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'βοδινό top-side (kg)'
#        type                                            product  \
# 135   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 303   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 471   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 638   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 806   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 1022  ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 1224  ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 1399  ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# ...

# %%
arr = (df['product'].str.find('λαπάς με κόκκαλο')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χοιρινός λαπάς με κόκκαλο (kg)'

# results    
df[(df['product'].str.find('λαπάς με κόκκαλο')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2502866548.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χοιρινός λαπάς με κόκκαλο (kg)'
#        type                                 product  \
# 129   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 297   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 465   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 632   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 800   ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 1029  ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 1218  ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 1406  ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 1596  ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# 1764  ΚΡΕΑΣ          χοιρινός λαπάς με κόκκαλο (kg)
# ...

# %%
arr = (df['product'].str.find('καλαμάρι μικρό')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'καλαμάρι μικρό  (kg)'

# results    
df[(df['product'].str.find('καλαμάρι μικρό')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1815238906.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'καλαμάρι μικρό  (kg)'
#                       type              product    normalized_product  \
# 143   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# 311   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# 479   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# 646   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# 814   ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# 1032  ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# 1232  ΦΡΕΣΚΑ ΨΑΡΙΑ/ΜΑΛΑΚΙΑ  καλαμάρι μικρό (kg)  καλαμάρι μικρό  (kg)
# ...

# %%
arr = (df['product'].str.find('αγγουράκια χωραφιού')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'αγγουράκια χωραφιού (kg)'

# results    
df[(df['product'].str.find('αγγουράκια χωραφιού (kg)')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2842391186.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'αγγουράκια χωραφιού (kg)'
#        type                   product        normalized_product  quantity  \
# 128   ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# 296   ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# 464   ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# 631   ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# 799   ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# 1039  ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# 1217  ΧΟΡΤΑ  αγγουράκια χωραφιού (kg)  αγγουράκια χωραφιού (kg)       1.0
# ...

# %%
arr = (df['product'].str.find('αγγουράκια θερμοκηπίου')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'αγγουράκια θερμοκηπίου (kg)'

# results    
df[(df['product'].str.find('αγγουράκια θερμοκηπίου (kg)')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1417438822.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'αγγουράκια θερμοκηπίου (kg)'
#        type                      product           normalized_product  \
# 127   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 295   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 463   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 630   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 798   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 1038  ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 1216  ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# ...

# %%
arr = (df['product'].str.find('ντομάτες (kg)')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'ντομάτες (kg)'

# results    
df[(df['product'].str.find('ντομάτες (kg)')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3382330495.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'ντομάτες (kg)'
#        type        product normalized_product  quantity   max   min   avg  \
# 3391  ΧΟΡΤΑ  ντομάτες (kg)      ντομάτες (kg)       1.0  1.80  0.69  1.37
# 3427  ΧΟΡΤΑ  ντομάτες (kg)      ντομάτες (kg)       1.0  2.75  1.50  2.20
# 3463  ΧΟΡΤΑ  ντομάτες (kg)      ντομάτες (kg)       1.0  2.49  1.29  1.84
#
#       month  year                               file
# 3391      2  2018  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3427      3  2019  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3463      3  2020  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας

# %%
arr = (df['product'].str.find('ντομάτες α')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'ντομάτες α (kg)'

# results    
df[(df['product'].str.find('ντομάτες α')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1711460818.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'ντομάτες α (kg)'
#        type          product normalized_product  quantity   max   min   avg  \
# 126   ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  3.40  2.15  2.89
# 294   ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  2.75  1.29  2.13
# 462   ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  1.45  0.40  0.88
# 629   ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  2.10  0.99  1.75
# 797   ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  3.99  0.90  3.17
# 1040  ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  1.91  0.99  1.44
# 1215  ΧΟΡΤΑ  ντομάτες α (kg)    ντομάτες α (kg)       1.0  1.35  0.70  1.05
# ...

# %%
arr = (df['product'].str.find('χόρτα')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χόρτα δέσμης'

# results    
df[(df['product'].str.find('χόρτα')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3310275915.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χόρτα δέσμης'
#        type       product normalized_product  quantity   max   min   avg  \
# 124   ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  0.45  0.27  0.34
# 292   ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  0.50  0.30  0.38
# 460   ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  0.45  0.15  0.32
# 627   ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  0.55  0.30  0.39
# 795   ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  0.45  0.27  0.34
# 1042  ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  1.82  0.37  0.48
# 1213  ΧΟΡΤΑ  χόρτα δέσμης       χόρτα δέσμης       1.0  0.45  0.25  0.33
# ...

# %%
arr = (df['product'].str.find('πατάτες')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'πατάτες φρέσκες (kg)'

# results    
df[(df['product'].str.find('πατάτες')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3798610258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'πατάτες φρέσκες (kg)'
#        type                product    normalized_product  quantity   max  \
# 125   ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.29
# 293   ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.29
# 461   ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.45
# 628   ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.59
# 796   ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.39
# 1041  ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  2.36
# 1214  ΧΟΡΤΑ   πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.10
# ...

# %%
arr = ((df['product'].str.find('αμνοερίφια')!= -1)&(df['product'].str.find('μικρά')!= -1)&(df['product'].str.find('ντόπια')!= -1)&(df['product'].str.find('ολόκληρα')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'αμνοερίφια μικρά ολόκληρα ντόπια (kg)'

# results    
df[(df['product'].str.find('αμνοερίφια')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1120950304.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'αμνοερίφια μικρά ολόκληρα ντόπια (kg)'
#        type                                     product  \
# 134   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 302   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 470   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 637   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 805   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 1021  ΚΡΕΑΣ           αμνοερίφια μικρά σε κομμάτια (kg)
# 1223  ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 1398  ΚΡΕΑΣ           αμνοερίφια μικρά σε κομμάτια (kg)
# 1601  ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# ...

# %%
arr = ((df['product'].str.find('αμνοερίφια')!= -1)&(df['product'].str.find('μικρά')!= -1)&(df['product'].str.find('ντόπια')!= -1)&(df['product'].str.find('ολόκληρα')== -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'αμνοερίφια μικρά ντόπια (kg)'

# results    
df[(df['product'].str.find('αμνοερίφια')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\315573998.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'αμνοερίφια μικρά ντόπια (kg)'
#        type                                     product  \
# 134   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 302   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 470   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 637   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 805   ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 1021  ΚΡΕΑΣ           αμνοερίφια μικρά σε κομμάτια (kg)
# 1223  ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# 1398  ΚΡΕΑΣ           αμνοερίφια μικρά σε κομμάτια (kg)
# 1601  ΚΡΕΑΣ                       αμνοερίφια μικρά (kg)
# ...

# %%
arr = (df['product'].str.find('christmas cake')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'christmas cake (kg)'

# results    
df[(df['product'].str.find('christmas cake')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1139319087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'christmas cake (kg)'
#                 type                                         product  \
# 3187  CHRISTMAS CAKE  christmas cake - ενδεικτική τιμή ανά κιλό (kg)
# 3212  CHRISTMAS CAKE  christmas cake - ενδεικτική τιμή ανά κιλό (kg)
# 3237  CHRISTMAS CAKE  christmas cake - ενδεικτική τιμή ανά κιλό (kg)
# 3262  CHRISTMAS CAKE  christmas cake - ενδεικτική τιμή ανά κιλό (kg)
# 3284  CHRISTMAS CAKE  christmas cake - ενδεικτική τιμή ανά κιλό (kg)
# 3309  CHRISTMAS CAKE  christmas cake - ενδεικτική τιμή ανά κιλό (kg)
#
#        normalized_product  quantity    max   min    avg  month  year  \
# ...

# %%
arr = (df['product'].str.find('κουραμπιέδες συσκευασμένοι 500g')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'κουραμπιέδες συσκευασμένοι 500g'

# results    
df[(df['product'].str.find('κουραμπιέδες συσκευασμένοι 500g')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2873740949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'κουραμπιέδες συσκευασμένοι 500g'
#               type                          product  \
# 3186  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες συσκευασμένοι 500g
# 3211  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες συσκευασμένοι 500g
# 3236  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες συσκευασμένοι 500g
# 3261  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες συσκευασμένοι 500g
# 3283  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες συσκευασμένοι 500g
# 3308  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες συσκευασμένοι 500g
#
#                    normalized_product  quantity   max   min   avg  month  \
# 3186  κουραμπιέδες συσκευασμένοι 500g       0.5   8.0  3.00  4.24     12
# 3211  κουραμπιέδες συσκευασμένοι 500g       0.5   6.5  3.49  4.56     12
# ...

# %%
arr = (df['product'].str.find('κουραμπιέδες με γέμιση φοινίκι (φοινικωτά)')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) (kg)'

# results    
df[(df['product'].str.find('κουραμπιέδες με γέμιση φοινίκι (φοινικωτά)')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1814338639.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) (kg)'
#               type                                         product  \
# 3162  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
# 3185  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
# 3210  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
# 3235  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
# 3260  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
# 3282  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
# 3307  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες με γέμιση φοινίκι (φοινικωτά) /kg
#
# ...

# %%
arr = (df['product'].str.find('κουραμπιέδες αμυγδάλου')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'κουραμπιέδες αμυγδάλου (kg)'

# results    
df[(df['product'].str.find('κουραμπιέδες αμυγδάλου')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1404087074.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'κουραμπιέδες αμυγδάλου (kg)'
#               type                     product           normalized_product  \
# 3161  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
# 3184  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
# 3209  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
# 3234  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
# 3259  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
# 3281  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
# 3306  ΚΟΥΡΑΜΠΙΕΔΕΣ  κουραμπιέδες αμυγδάλου /kg  κουραμπιέδες αμυγδάλου (kg)
#
# ...

# %%
arr = (df['product'].str.find('μελομακάρονα συσκευασμένα 500g')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'μελομακάρονα συσκευασμένα 500g'

# results    
df[(df['product'].str.find('μελομακάρονα συσκευασμένα 500g')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1604371423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'μελομακάρονα συσκευασμένα 500g'
#               type                         product  \
# 3183  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα συσκευασμένα 500g
# 3208  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα συσκευασμένα 500g
# 3233  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα συσκευασμένα 500g
# 3258  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα συσκευασμένα 500g
# 3280  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα συσκευασμένα 500g
# 3305  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα συσκευασμένα 500g
#
#                   normalized_product  quantity   max   min   avg  month  year  \
# 3183  μελομακάρονα συσκευασμένα 500g       0.5  4.95  3.00  4.00     12  2017
# 3208  μελομακάρονα συσκευασμένα 500g       0.5  6.95  3.49  4.76     12  2018
# ...

# %%
arr = (df['product'].str.find('μελομακάρονα επικαλυμμένα με σοκολάτα')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'μελομακάρονα επικαλυμμένα με σοκολάτα (kg)'

# results    
df[(df['product'].str.find('μελομακάρονα επικαλυμμένα με σοκολάτα')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\410124077.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'μελομακάρονα επικαλυμμένα με σοκολάτα (kg)'
#               type                                    product  \
# 3182  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα επικαλυμμένα με σοκολάτα /kg
# 3207  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα επικαλυμμένα με σοκολάτα /kg
# 3232  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα επικαλυμμένα με σοκολάτα /kg
# 3257  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα επικαλυμμένα με σοκολάτα /kg
# 3279  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα επικαλυμμένα με σοκολάτα /kg
# 3304  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα επικαλυμμένα με σοκολάτα /kg
#
#                               normalized_product  quantity   max    min  \
# 3182  μελομακάρονα επικαλυμμένα με σοκολάτα (kg)       1.0  14.5   8.90
# ...

# %%
arr = (df['product'].str.find('μελομακάρονα /kg')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'μελομακάρονα (kg)'

# results    
df[(df['product'].str.find('μελομακάρονα /kg')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2479848616.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'μελομακάρονα (kg)'
#               type           product normalized_product  quantity   max   min  \
# 3160  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  12.5  5.99
# 3181  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  14.0  6.49
# 3206  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  16.0  6.99
# 3231  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  16.0  6.99
# 3256  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  16.0  7.50
# 3278  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  17.0  8.49
# 3303  ΜΕΛΟΜΑΚΑΡΟΝΑ  μελομακάρονα /kg  μελομακάρονα (kg)       1.0  18.5  8.50
# ...

# %%
arr = (df['product'].str.find('γαλοπούλα εισαγόμενη')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'γαλοπούλα εισαγόμενη (kg)'

# results    
df[(df['product'].str.find('γαλοπούλα εισαγόμενη')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2100553627.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'γαλοπούλα εισαγόμενη (kg)'
#        type                   product         normalized_product  quantity  \
# 3180  ΚΡΕΑΣ  γαλοπούλα εισαγόμενη /kg  γαλοπούλα εισαγόμενη (kg)       1.0
# 3205  ΚΡΕΑΣ  γαλοπούλα εισαγόμενη /kg  γαλοπούλα εισαγόμενη (kg)       1.0
# 3230  ΚΡΕΑΣ  γαλοπούλα εισαγόμενη /kg  γαλοπούλα εισαγόμενη (kg)       1.0
# 3255  ΚΡΕΑΣ  γαλοπούλα εισαγόμενη /kg  γαλοπούλα εισαγόμενη (kg)       1.0
# 3302  ΚΡΕΑΣ  γαλοπούλα εισαγόμενη /kg  γαλοπούλα εισαγόμενη (kg)       1.0
#
#        max   min   avg  month  year                             file
# 3180  5.50  3.45  4.02     12  2017  ΠαρατηρητήτιοΤιμώνΧριστουγέννων
# ...

# %%
arr = (df['product'].str.find('γαλοπούλα ντόπια')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'γαλοπούλα ντόπια (kg)'

# results    
df[(df['product'].str.find('γαλοπούλα ντόπια')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\439179041.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'γαλοπούλα ντόπια (kg)'
#        type               product     normalized_product  quantity   max  \
# 3159  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  6.75
# 3179  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  6.50
# 3204  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  6.50
# 3229  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  6.50
# 3254  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  6.00
# 3277  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  6.90
# 3301  ΚΡΕΑΣ  γαλοπούλα ντόπια /kg  γαλοπούλα ντόπια (kg)       1.0  8.05
#
# ...

# %%
arr = (df['product'].str.find('φλαούνες με σταφιδάκια')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'φλαούνες με σταφιδάκια (kg)'

# results    
df[(df['product'].str.find('φλαούνες με σταφιδάκια')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2746953134.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'φλαούνες με σταφιδάκια (kg)'
#           type                     product           normalized_product  \
# 3326  ΦΛΑΟΥΝΕΣ  φλαούνες με σταφιδάκια /kg  φλαούνες με σταφιδάκια (kg)
# 3338  ΦΛΑΟΥΝΕΣ  φλαούνες με σταφιδάκια /kg  φλαούνες με σταφιδάκια (kg)
# 3350  ΦΛΑΟΥΝΕΣ  φλαούνες με σταφιδάκια /kg  φλαούνες με σταφιδάκια (kg)
# 3362  ΦΛΑΟΥΝΕΣ  φλαούνες με σταφιδάκια /kg  φλαούνες με σταφιδάκια (kg)
# 3374  ΦΛΑΟΥΝΕΣ  φλαούνες με σταφιδάκια /kg  φλαούνες με σταφιδάκια (kg)
# 3386  ΦΛΑΟΥΝΕΣ  φλαούνες με σταφιδάκια /kg  φλαούνες με σταφιδάκια (kg)
#
#       quantity    max   min    avg  month  year                     file
# ...

# %%
arr = (df['product'].str.find('φλαούνες αλμυρές')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'φλαούνες αλμυρές (kg)'

# results    
df[(df['product'].str.find('φλαούνες αλμυρές')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3141517005.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'φλαούνες αλμυρές (kg)'
#           type               product     normalized_product  quantity    max  \
# 3325  ΦΛΑΟΥΝΕΣ  φλαούνες αλμυρές /kg  φλαούνες αλμυρές (kg)       1.0  15.00
# 3337  ΦΛΑΟΥΝΕΣ  φλαούνες αλμυρές /kg  φλαούνες αλμυρές (kg)       1.0  14.95
# 3349  ΦΛΑΟΥΝΕΣ  φλαούνες αλμυρές /kg  φλαούνες αλμυρές (kg)       1.0  14.95
# 3361  ΦΛΑΟΥΝΕΣ  φλαούνες αλμυρές /kg  φλαούνες αλμυρές (kg)       1.0  14.95
# 3373  ΦΛΑΟΥΝΕΣ  φλαούνες αλμυρές /kg  φλαούνες αλμυρές (kg)       1.0  16.00
# 3385  ΦΛΑΟΥΝΕΣ  φλαούνες αλμυρές /kg  φλαούνες αλμυρές (kg)       1.0  16.00
#
#        min    avg  month  year                     file
# ...

# %%
arr = (df['product'].str.find('ψωμί άσπρο μικρό')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'ψωμί άσπρο μικρό 500gr'

# results    
df[(df['product'].str.find('ψωμί άσπρο μικρό')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3653051056.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'ψωμί άσπρο μικρό 500gr'
#        type                                          product  \
# 147    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 315    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 483    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 650    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 818    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1048  ΧΟΡΤΑ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1236   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1425   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1614   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# ...

# %%
arr = (df['product'].str.find('ψωμί άσπρο μεγάλο')!= -1)
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'ψωμί άσπρο μεγάλο (kg)'

# results    
df[(df['product'].str.find('ψωμί άσπρο μεγάλο')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3063129786.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'ψωμί άσπρο μεγάλο (kg)'
#        type                                            product  \
# 146    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 314    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 482    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 649    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 817    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1047  ΧΟΡΤΑ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1235   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1424   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# ...

# %%
arr = ((df['product'].str.find('χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr')!= -1)|(df['product'].str.find('charalambides christis full fat 3% hdpe 2l')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'

# results    
df[(df['product'].str.find('χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\2715240032.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'
#              type                                       product  \
# 27    ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 195   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 363   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 530   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 698   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 1116  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 1494  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 1662  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# ...

# %%
arr = ((df['product'].str.find('λανιτης πλήρες (κόκκινο) 2ltr')!= -1)|(df['product'].str.find('lanitis full fat 3% hdpe 2l')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'λανιτης πλήρες (κόκκινο) 2ltr'

# results    
df[(df['product'].str.find('λανιτης πλήρες (κόκκινο) 2ltr')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3841851809.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'λανιτης πλήρες (κόκκινο) 2ltr'
#              type                        product  \
# 32    ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 200   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 368   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 535   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 703   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 1121  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 1499  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 1667  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 1835  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 2003  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# 2171  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης πλήρες (κόκκινο) 2ltr
# ...

# %%
arr = ((df['product'].str.find('λανιτης ημιάπαχο (κίτρινο) 2ltr')!= -1)|(df['product'].str.find('lanitis semi skimmed 1.5% hdpe 2l')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'λανιτης ημιάπαχο (κίτρινο) 2ltr'

# results    
df[(df['product'].str.find('λανιτης ημιάπαχο (κίτρινο) 2ltr')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3243695344.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'λανιτης ημιάπαχο (κίτρινο) 2ltr'
#              type                          product  \
# 28    ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 196   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 364   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 531   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 699   ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 1117  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 1495  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 1663  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 1831  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# 1999  ΦΡΕΣΚΟ ΓΑΛΑ  λανιτης ημιάπαχο (κίτρινο) 2ltr
# ...

# %%
arr = ((df['product'].str.find('χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr')!= -1)|(df['product'].str.find('charalambides christis semi skimmed 1.5% hdpe 2l')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr'

# results    
df[(df['product'].str.find('χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\516557045.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr'
#              type                                         product  \
# 25    ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 193   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 361   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 528   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 696   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 1114  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 1492  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# 1660  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης ημιάπαχο (κίτρινο) 2ltr
# ...

# %%
df[(df['type'].str.find('ΓΙΑΟΥΡΤΙ')!= -1)&(df['year'] ==2023)]
# Out:
#           type                                           product  \
# 857   ΓΙΑΟΥΡΤΙ             alambra the granny sheep f/f pc 700gr
# 858   ΓΙΑΟΥΡΤΙ  charalamb/christis strained straggato f/f pc 1kg
# 859   ΓΙΑΟΥΡΤΙ  charalamb/christis strained straggato lgt pc 1kg
# 860   ΓΙΑΟΥΡΤΙ                          zita strained f/f pc 1kg
# 861   ΓΙΑΟΥΡΤΙ                          zita strained lgt pc 1kg
# 1275  ΓΙΑΟΥΡΤΙ             alambra the granny sheep f/f pc 700gr
# 1276  ΓΙΑΟΥΡΤΙ  charalamb/christis strained straggato f/f pc 1kg
# 1277  ΓΙΑΟΥΡΤΙ  charalamb/christis strained straggato lgt pc 1kg
# 1278  ΓΙΑΟΥΡΤΙ                          zita strained f/f pc 1kg
# 1279  ΓΙΑΟΥΡΤΙ                          zita strained lgt pc 1kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 857                 NaN       0.7  4.30  2.39  2.94      2  2023
# 858                 NaN       1.0  6.00  3.80  4.12      2  2023
# ...

# %%
arr = ((df['product'].str.find('χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)')!= -1)|(df['product'].str.find('charalamb/christis strained straggato f/f pc 1kg')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'

# results    
df[(df['product'].str.find('χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)')!= -1)|(df['product'].str.find('charalamb/christis strained straggato f/f pc 1kg')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\3581669592.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'
#           type                                            product  \
# 34    ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 36    ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 202   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 204   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 370   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 537   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 539   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# ...

# %%
arr = ((df['product'].str.find('super στραγγιστό 1kg')!= -1)|(df['product'].str.find('zita strained f/f pc 1kg')!= -1))
for i in range(len(df)):
   if (arr[i]):
     df['normalized_product'][i] = 'ζητα super στραγγιστό 1kg (μπλέ συσκ.) f/f'

# results    
df[(df['product'].str.find('super στραγγιστό 1kg')!= -1)|(df['product'].str.find('zita strained f/f pc 1kg')!= -1)]
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_3712\1886026112.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized_product'][i] = 'ζητα super στραγγιστό 1kg (μπλέ συσκ.) f/f'
#           type                                 product  \
# 37    ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 205   ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 373   ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 540   ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 708   ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 860   ΓΙΑΟΥΡΤΙ                zita strained f/f pc 1kg
# 1126  ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 1278  ΓΙΑΟΥΡΤΙ                zita strained f/f pc 1kg
# 1504  ΓΙΑΟΥΡΤΙ  ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# ...

# %%
df.to_csv('../Data/FinalData/EditedFinal.csv', encoding = 'utf-8-sig', index = False)

# %%
newdata = pd.read_csv('../Data/FinalData/EditedFinal.csv')
newdf = pd.DataFrame(newdata)
newdf
# Out:
#           type                                            product  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...        ...                                                ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 0                   NaN      1.00  6.89  3.89  5.62      4  2022
# ...
