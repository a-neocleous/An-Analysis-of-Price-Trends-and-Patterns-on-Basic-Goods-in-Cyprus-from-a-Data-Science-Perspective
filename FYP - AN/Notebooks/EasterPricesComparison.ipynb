# %% [markdown]
# # <b><font color= 'red'> COMP494,495 – Final Year Project</font></b>
#
# ## <b>Andreas Neocleous<b>
#
# #### Easter Prices Comparison

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
newdata = pd.read_csv('../Data/FinalData/EditedFinal.csv')
newdf = pd.DataFrame(newdata)
newdf
# Out:
#           type                                            product  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...        ...                                                ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 0                   NaN      1.00  6.89  3.89  5.62      4  2022
# 1                   NaN      1.00  2.82  1.77  2.12      4  2022
# 2                   NaN      1.00  4.07  2.75  3.48      4  2022
# 3                   NaN      1.00  4.59  2.65  3.24      4  2022
# 4                   NaN      1.00  2.69  1.35  1.84      4  2022
# ...                 ...       ...   ...   ...   ...    ...   ...
# 3580                NaN      1.00  2.40  1.10  1.75      3  2022
# 3581                NaN      0.75  4.50  2.35  3.08      3  2022
# 3582                NaN      0.75  5.20  2.35  3.68      3  2022
# 3583                NaN      5.00  5.50  3.99  4.69      3  2022
# 3584                NaN      5.00  5.28  3.99  4.50      3  2022
#
#                                    file
# 0               ΒασικάΚαταναλωτικάΑγαθά
# 1               ΒασικάΚαταναλωτικάΑγαθά
# 2               ΒασικάΚαταναλωτικάΑγαθά
# 3               ΒασικάΚαταναλωτικάΑγαθά
# 4               ΒασικάΚαταναλωτικάΑγαθά
# ...                                 ...
# 3580  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3581  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3582  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3583  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
# 3584  ΠαρατηρητήτιοΤιμώνΚαθαράςΔευτέρας
#
# [3585 rows x 10 columns]

# %% [markdown]
# ### 2022

# %%
easterComparison= newdata[(newdata['month'] == 4) & (newdata['year'] == 2022) & (newdata['type'] == 'ΚΡΕΑΣ')]
easterComparison
# Out:
#        type                                            product  \
# 129   ΚΡΕΑΣ                     χοιρινός λαπάς με κόκκαλο (kg)
# 130   ΚΡΕΑΣ                       χοιρινή μπριζόλα φιλέτο (kg)
# 131   ΚΡΕΑΣ                     χοιρινός κιμάς (από μερί) (kg)
# 132   ΚΡΕΑΣ          κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 133   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 134   ΚΡΕΑΣ                              αμνοερίφια μικρά (kg)
# 135   ΚΡΕΑΣ  βοδινό top-side (kg) (ψαχνό, χωρίς κόκκαλο και...
# 136   ΚΡΕΑΣ       βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)
# 137   ΚΡΕΑΣ                     κουνέλι (kg) (χαμηλότερη τιμή)
# 3375  ΚΡΕΑΣ                        αμνοερίφια μικρά ντόπια 1kg
# 3376  ΚΡΕΑΣ               αμνοερίφια μικρά ολόκληρα ντόπια 1kg
# 3377  ΚΡΕΑΣ                      χοιρινός λαπάς με κόκκαλο 1kg
# 3378  ΚΡΕΑΣ                       χοιρινή μπριζόλα φιλλέτο 1kg
# 3379  ΚΡΕΑΣ                      χοιρινός κιμάς 1kg (από μερί)
# 3380  ΚΡΕΑΣ  βοδινό top-side ντόπιο 1kg (ψαχνό, χωρίς κόκκα...
# 3381  ΚΡΕΑΣ        βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)
# 3382  ΚΡΕΑΣ           κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
# 3383  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
# 3384  ΚΡΕΑΣ               κουνέλι ντόπιο 1kg (χαμηλότερη τιμή)
#
#                          normalized_product  quantity    max   min    avg  \
# 129          χοιρινός λαπάς με κόκκαλο (kg)       1.0   6.40  3.89   5.22
# 130            χοιρινή μπριζόλα φιλέτο (kg)       1.0   6.40  4.25   4.89
# 131                                     NaN       1.0   6.90  3.69   4.78
# 132                 κοτόπουλο ολόκληρο (kg)       1.0   4.50  2.59   3.74
# 133                   κοτόπουλο φιλέτο (kg)       1.0   9.99  5.95   7.87
# 134                                     NaN       1.0  11.00  7.35   8.39
# 135                    βοδινό top-side (kg)       1.0  12.99  6.95   9.90
# 136                      βοδινός κιμάς (kg)       1.0  10.00  5.95   7.55
# 137                                     NaN       1.0  10.49  8.25   9.30
# 3375           αμνοερίφια μικρά ντόπια (kg)       1.0  11.00  6.95   9.04
# 3376  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.00  6.99   8.55
# 3377         χοιρινός λαπάς με κόκκαλο (kg)       1.0   6.90  4.29   5.63
# 3378           χοιρινή μπριζόλα φιλέτο (kg)       1.0   6.80  3.95   5.46
# 3379                                    NaN       1.0   7.50  2.99   5.61
# 3380            βοδινό top-side ντόπιο (kg)       1.0  13.80  6.95  10.37
# 3381                     βοδινός κιμάς (kg)       1.0  12.00  5.95   8.73
# 3382                κοτόπουλο ολόκληρο (kg)       1.0   5.20  2.59   4.18
# 3383                  κοτόπουλο φιλέτο (kg)       1.0  10.40  5.99   8.41
# 3384                                    NaN       1.0  11.40  8.00   9.27
#
#       month  year                     file
# 129       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 130       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 131       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 132       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 133       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 134       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 135       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 136       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 137       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 3375      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3376      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3377      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3378      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3379      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3380      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3381      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3382      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3383      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3384      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα

# %% [markdown]
# #### Κοτόπουλο Φιλέτο (kg)

# %%
temp = easterComparison[(easterComparison['normalized_product'] == 'κοτόπουλο φιλέτο (kg)')]
temp
# Out:
#        type                                            product  \
# 133   ΚΡΕΑΣ     κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 3383  ΚΡΕΑΣ  νωπό κοτόπουλο στήθος φιλέττο 1kg (χαμηλοτ. τιμή)
#
#          normalized_product  quantity    max   min   avg  month  year  \
# 133   κοτόπουλο φιλέτο (kg)       1.0   9.99  5.95  7.87      4  2022
# 3383  κοτόπουλο φιλέτο (kg)       1.0  10.40  5.99  8.41      4  2022
#
#                          file
# 133   ΒασικάΚαταναλωτικάΑγαθά
# 3383  ΠαρατηρητήτιοΤιμώνΠάσχα

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Πάσχα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Κοτόπουλο Ολόκληρο (kg)

# %%
temp = easterComparison[(easterComparison['normalized_product'] == 'κοτόπουλο ολόκληρο (kg)')]
temp
# Out:
#        type                                    product  \
# 132   ΚΡΕΑΣ  κοτόπουλο ολόκληρο (kg) (χαμηλότερη τιμή)
# 3382  ΚΡΕΑΣ   κοτόπουλο ολόκληρο 1kg (χαμηλότερη τιμή)
#
#            normalized_product  quantity  max   min   avg  month  year  \
# 132   κοτόπουλο ολόκληρο (kg)       1.0  4.5  2.59  3.74      4  2022
# 3382  κοτόπουλο ολόκληρο (kg)       1.0  5.2  2.59  4.18      4  2022
#
#                          file
# 132   ΒασικάΚαταναλωτικάΑγαθά
# 3382  ΠαρατηρητήτιοΤιμώνΠάσχα

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Πάσχα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Ολόκληρο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινή Μπριζόλα Φιλέτο (kg)

# %%
temp = easterComparison[(easterComparison['normalized_product'] == 'χοιρινή μπριζόλα φιλέτο (kg)')]
temp
# Out:
#        type                       product            normalized_product  \
# 130   ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 3378  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλλέτο 1kg  χοιρινή μπριζόλα φιλέτο (kg)
#
#       quantity  max   min   avg  month  year                     file
# 130        1.0  6.4  4.25  4.89      4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 3378       1.0  6.8  3.95  5.46      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Πάσχα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Βοδινός Κιμάς (kg)

# %%
temp = easterComparison[(easterComparison['normalized_product'] == 'βοδινός κιμάς (kg)')]
temp
# Out:
#        type                                       product  normalized_product  \
# 136   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 3381  ΚΡΕΑΣ   βοδινός κιμάς 1kg (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
#
#       quantity   max   min   avg  month  year                     file
# 136        1.0  10.0  5.95  7.55      4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 3381       1.0  12.0  5.95  8.73      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Πάσχα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινός Λαπάς Με Κόκκαλο (kg)

# %%
temp = easterComparison[(easterComparison['normalized_product'] == 'χοιρινός λαπάς με κόκκαλο (kg)')]
temp
# Out:
#        type                         product              normalized_product  \
# 129   ΚΡΕΑΣ  χοιρινός λαπάς με κόκκαλο (kg)  χοιρινός λαπάς με κόκκαλο (kg)
# 3377  ΚΡΕΑΣ   χοιρινός λαπάς με κόκκαλο 1kg  χοιρινός λαπάς με κόκκαλο (kg)
#
#       quantity  max   min   avg  month  year                     file
# 129        1.0  6.4  3.89  5.22      4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 3377       1.0  6.9  4.29  5.63      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα

# %%
fig, axes = plt.subplots(3, 1, figsize=(5,7))
plt.suptitle('Σύγκριση Τιμών: Βασικά Καταναλωτικά Αγαθά - Πάσχα 2022', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινός Λαπάς Με Κόκκαλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)

axes[0].scatter(data=temp, x='file',y='min', color = 'green', alpha=0.8)
axes[0].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[1].scatter(data=temp, x='file',y='max', color = 'red', alpha=0.8)
axes[1].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)

axes[2].scatter(data=temp, x='file',y='avg', color = 'b', alpha=0.8)
axes[2].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Αμνοερίφια

# %%
easterComparison[(easterComparison['product'].str.find('αμν')!= -1)]
# Out:
#        type                               product  \
# 134   ΚΡΕΑΣ                 αμνοερίφια μικρά (kg)
# 3375  ΚΡΕΑΣ           αμνοερίφια μικρά ντόπια 1kg
# 3376  ΚΡΕΑΣ  αμνοερίφια μικρά ολόκληρα ντόπια 1kg
#
#                          normalized_product  quantity   max   min   avg  \
# 134                                     NaN       1.0  11.0  7.35  8.39
# 3375           αμνοερίφια μικρά ντόπια (kg)       1.0  11.0  6.95  9.04
# 3376  αμνοερίφια μικρά ολόκληρα ντόπια (kg)       1.0  10.0  6.99  8.55
#
#       month  year                     file
# 134       4  2022  ΒασικάΚαταναλωτικάΑγαθά
# 3375      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα
# 3376      4  2022  ΠαρατηρητήτιοΤιμώνΠάσχα

# %% [markdown]
# Για το συγκεκριμένο προϊόν δεν υπάρχει κοινή περιγραφή, ως εκ τουτου δεν θα προχωρίσουμε σε σύγκριση τιμών και γραφική αναπαράσταση
