# %% [markdown]
# # <b><font color= 'red'> COMP494,495 – Final Year Project</font></b>
#
# ## <b>Andreas Neocleous<b>
#
# #### Basic Goods Comparison

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pandas import Grouper
from datetime import datetime

# %%
newdata = pd.read_csv('../Data/FinalData/EditedFinal.csv')
newdf = pd.DataFrame(newdata)
newdf
# Out:
#           type                                            product  \
# 0         ΡΥΖΙ                    tilda pure basmati original 1kg
# 1         ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2         ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3         ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4         ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...        ...                                                ...
# 3580      ΨΩΜΙ                           ελιωτή χωριάτικη τεμάχιο
# 3581    ΚΡΑΣΙΑ                     keo othello (ερυθρό ξηρό) 75cl
# 3582    ΚΡΑΣΙΑ                       afames 62 (ερυθρό ξηρό) 75cl
# 3583  ΚΑΡΒΟΥΝΑ                                κάρβουνα πυρσός 5kg
# 3584  ΚΑΡΒΟΥΝΑ                                κάρβουνα ετοsha 5kg
#
#      normalized_product  quantity   max   min   avg  month  year  \
# 0                   NaN      1.00  6.89  3.89  5.62      4  2022
# ...

# %%
basic= newdata[(newdata['file'] == 'ΒασικάΚαταναλωτικάΑγαθά')]
basic
# Out:
#                      type                                            product  \
# 0                    ΡΥΖΙ                    tilda pure basmati original 1kg
# 1                    ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2                    ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3                    ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4                    ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...                   ...                                                ...
# 3141  ΝΤΟΜΑΤΟΧΥΜΟΣ/ΠΕΛΤΕΣ                      blossom πάστα ντομάτας 4χ70gr
# 3142  ΝΤΟΜΑΤΟΧΥΜΟΣ/ΠΕΛΤΕΣ                          sws πουρές τομάτας 4χ70gr
# 3143  ΝΤΟΜΑΤΟΧΥΜΟΣ/ΠΕΛΤΕΣ                         maggi ζωμός κότας 12 κύβοι
# 3144  ΝΤΟΜΑΤΟΧΥΜΟΣ/ΠΕΛΤΕΣ                        blossom πάστα ντομάτας 70gr
# 3145  ΚΥΛΙΝΔΡΟΣ ΥΓΡΑΕΡΙΟΥ          κυλινδρος 10kg (τιμη με επιστροφη αδειου)
#
# ...

# %%
basic['date'] = basic.apply(lambda x: str(x['month']) + '-' + str(x['year']), axis = 1)
basic
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_12080\3155186341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basic['date'] = basic.apply(lambda x: str(x['month']) + '-' + str(x['year']), axis = 1)
#                      type                                            product  \
# 0                    ΡΥΖΙ                    tilda pure basmati original 1kg
# 1                    ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2                    ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3                    ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4                    ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...

# %%
basic['date'] = basic['date'].apply(lambda x: datetime.strptime(x,'%m-%Y'))
basic
# Out:
# C:\Users\pambo\AppData\Local\Temp\ipykernel_12080\2240720171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basic['date'] = basic['date'].apply(lambda x: datetime.strptime(x,'%m-%Y'))
#                      type                                            product  \
# 0                    ΡΥΖΙ                    tilda pure basmati original 1kg
# 1                    ΡΥΖΙ     σολεας 3a rice glasse (σούπες και γεμιστά) 1kg
# 2                    ΡΥΖΙ  uncle bens ρύζι μακρύκοκκο - parboiled (20 λεπ...
# 3                    ΡΥΖΙ      σολεας 3a ρύζι basmati αυθεντικό αρωματικό1kg
# 4                    ΡΥΖΙ  σολεας 3a rice parboiled (πράσινη συσκευασία) 1kg
# ...                   ...                                                ...
# ...

# %% [markdown]
# #### Κοτόπουλο Φιλέτο (kg)

# %%
temp = basic[basic['normalized_product'] == 'κοτόπουλο φιλέτο (kg)']
temp
# Out:
#        type                                         product  \
# 133   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 301   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 469   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 636   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 804   ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1025  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1222  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1402  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1600  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1768  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 1936  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 2104  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 2272  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 2440  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# 2608  ΚΡΕΑΣ  κοτόπουλο στήθος φιλέτο (kg) (χαμηλότερη τιμή)
# ...

# %%
maximum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
ax = maximum.plot(color = 'r', marker='.', alpha=0.8)

average = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
average.plot(ax = ax , marker='.', alpha=0.8)

minimum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))
minimum.plot(ax = ax ,color = 'g', marker='.', alpha=0.8)

plt.suptitle('Βασικά Καταναλωτικά Αγαθά ', color = 'C3', fontsize = 16)
plt.xlabel('Κοτόπουλο Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Χοιρινή Μπριζόλα Φιλέτο (kg)

# %%
temp = basic[basic['normalized_product'] == 'χοιρινή μπριζόλα φιλέτο (kg)']
temp
# Out:
#        type                       product            normalized_product  \
# 130   ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 298   ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 466   ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 633   ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 801   ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1027  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1219  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1404  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1597  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1765  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 1933  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# 2101  ΚΡΕΑΣ  χοιρινή μπριζόλα φιλέτο (kg)  χοιρινή μπριζόλα φιλέτο (kg)
# ...

# %%
maximum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
ax = maximum.plot(color = 'r', marker='.', alpha=0.8)

average = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
average.plot(ax = ax , marker='.', alpha=0.8)

minimum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))
minimum.plot(ax = ax ,color = 'g', marker='.', alpha=0.8)

plt.suptitle('Βασικά Καταναλωτικά Αγαθά ', color = 'C3', fontsize = 16)
plt.xlabel('Χοιρινή Μπριζόλα Φιλέτο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Βοδινός Κιμάς (kg)

# %%
temp = basic[basic['normalized_product'] == 'βοδινός κιμάς (kg)']
temp
# Out:
#        type                                       product  normalized_product  \
# 136   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 304   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 472   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 639   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 807   ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1023  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1225  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1400  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1603  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1771  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# 1939  ΚΡΕΑΣ  βοδινός κιμάς (kg) (από κουτάλα καθαρισμένη)  βοδινός κιμάς (kg)
# ...

# %%
maximum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
ax = maximum.plot(color = 'r', marker='.', alpha=0.8)

average = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
average.plot(ax = ax , marker='.', alpha=0.8)

minimum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))
minimum.plot(ax = ax ,color = 'g', marker='.', alpha=0.8)

plt.suptitle('Βασικά Καταναλωτικά Αγαθά ', color = 'C3', fontsize = 16)
plt.xlabel('Βοδινός Κιμάς (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Ψωμί Άσπρο Μεγάλο (kg)

# %%
temp = basic[basic['normalized_product'] == 'ψωμί άσπρο μεγάλο (kg)']
temp
# Out:
#        type                                            product  \
# 146    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 314    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 482    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 649    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 817    ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1047  ΧΟΡΤΑ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1235   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1424   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1613   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1781   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 1949   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 2117   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 2285   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# 2453   ΨΩΜΙ  ψωμί άσπρο μεγάλο (900gr - 1000gr) (χαμηλότερη...
# ...

# %%
maximum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
ax = maximum.plot(color = 'r', marker='.', alpha=0.8)

average = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
average.plot(ax = ax , marker='.', alpha=0.8)

minimum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))
minimum.plot(ax = ax ,color = 'g', marker='.', alpha=0.8)

plt.suptitle('Βασικά Καταναλωτικά Αγαθά ', color = 'C3', fontsize = 16)
plt.xlabel('Ψωμί Άσπρο Μεγάλο (kg)', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Ψωμί Άσπρο Μικρό 500gr

# %%
temp = basic[basic['normalized_product'] == 'ψωμί άσπρο μικρό 500gr']
temp
# Out:
#        type                                          product  \
# 147    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 315    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 483    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 650    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 818    ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1048  ΧΟΡΤΑ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1236   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1425   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1614   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1782   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 1950   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 2118   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 2286   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# 2454   ΨΩΜΙ  ψωμί άσπρο μικρό (450gr-500gr)(χαμηλότερη τιμή)
# ...

# %%
maximum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
ax = maximum.plot(color = 'r', marker='.', alpha=0.8)

average = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
average.plot(ax = ax , marker='.', alpha=0.8)

minimum = (temp.groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))
minimum.plot(ax = ax ,color = 'g', marker='.', alpha=0.8)

plt.suptitle('Βασικά Καταναλωτικά Αγαθά ', color = 'C3', fontsize = 16)
plt.xlabel('Ψωμί Άσπρο Μικρό 500gr', color = 'C0', labelpad = 20, fontsize = 12)
plt.ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0, 0.5, 'Μέση Τιμή')

# %% [markdown]
# #### Γάλα

# %%
temp = basic[(basic['normalized_product'] == 'λανιτης πλήρες (κόκκινο) 2ltr')|(basic['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr')]
temp
# Out:
#              type                                       product  \
# 27    ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 32    ΦΡΕΣΚΟ ΓΑΛΑ                 λανιτης πλήρες (κόκκινο) 2ltr
# 195   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 200   ΦΡΕΣΚΟ ΓΑΛΑ                 λανιτης πλήρες (κόκκινο) 2ltr
# 363   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 368   ΦΡΕΣΚΟ ΓΑΛΑ                 λανιτης πλήρες (κόκκινο) 2ltr
# 530   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 535   ΦΡΕΣΚΟ ΓΑΛΑ                 λανιτης πλήρες (κόκκινο) 2ltr
# 698   ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 703   ΦΡΕΣΚΟ ΓΑΛΑ                 λανιτης πλήρες (κόκκινο) 2ltr
# 876   ΦΡΕΣΚΟ ΓΑΛΑ    charalambides christis full fat 3% hdpe 2l
# 880   ΦΡΕΣΚΟ ΓΑΛΑ                   lanitis full fat 3% hdpe 2l
# 1116  ΦΡΕΣΚΟ ΓΑΛΑ  χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 1121  ΦΡΕΣΚΟ ΓΑΛΑ                 λανιτης πλήρες (κόκκινο) 2ltr
# ...

# %%
maximum = (temp[temp['normalized_product'] == 'λανιτης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
average = (temp[temp['normalized_product'] == 'λανιτης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
minimum = (temp[temp['normalized_product'] == 'λανιτης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))

maximum2 = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'sum'}))
average2 = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'sum'}))
minimum2 = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'sum'}))

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
plt.suptitle('Βασικά Καταναλωτικά Αγαθά', color = 'C3', fontsize = 16)

maximum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[0])
maximum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[0])
axes[0].legend({'Χαραλαμπίδης','Λανίτης'}, frameon=True)
axes[0].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)


average.plot(color = 'g', marker='.', alpha=0.8, ax=axes[1])
average2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[1])
axes[1].legend('', frameon=False)
axes[1].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Γάλα Πλήρες (κόκκινο) 2ltr', color = 'C0', labelpad = 20, fontsize = 12)

minimum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[2])
minimum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[2])
axes[2].legend('', frameon=False)
axes[2].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Γιαούρτι

# %%
temp = basic[(basic['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f')|(basic['normalized_product'] == 'ζητα super στραγγιστό 1kg (μπλέ συσκ.) f/f')]
temp
# Out:
#           type                                            product  \
# 34    ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 36    ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 37    ΓΙΑΟΥΡΤΙ             ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 202   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 204   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 205   ΓΙΑΟΥΡΤΙ             ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 370   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 373   ΓΙΑΟΥΡΤΙ             ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 537   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 539   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 540   ΓΙΑΟΥΡΤΙ             ζητα super στραγγιστό 1kg (μπλέ συσκ.)
# 705   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 707   ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# ...

# %%
maximum = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

maximum2 = (temp[temp['normalized_product'] == 'ζητα super στραγγιστό 1kg (μπλέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average2 = (temp[temp['normalized_product'] == 'ζητα super στραγγιστό 1kg (μπλέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum2 = (temp[temp['normalized_product'] == 'ζητα super στραγγιστό 1kg (μπλέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
plt.suptitle('Βασικά Καταναλωτικά Αγαθά', color = 'C3', fontsize = 16)

maximum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[0])
maximum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[0])
axes[0].legend({'Χαραλαμπίδης','Ζήτα'}, frameon=True)
axes[0].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)


average.plot(color = 'g', marker='.', alpha=0.8, ax=axes[1])
average2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[1])
axes[1].legend('', frameon=False)
axes[1].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Γιαούρτι', color = 'C0', labelpad = 20, fontsize = 12)

minimum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[2])
minimum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[2])
axes[2].legend('', frameon=False)
axes[2].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Χαραλαμπίδης

# %%
temp = basic[(basic['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f')|(basic['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr')]
temp
# Out:
#              type                                            product  \
# 27    ΦΡΕΣΚΟ ΓΑΛΑ       χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 34       ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 36       ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 195   ΦΡΕΣΚΟ ΓΑΛΑ       χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 202      ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 204      ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 363   ΦΡΕΣΚΟ ΓΑΛΑ       χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 370      ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 530   ΦΡΕΣΚΟ ΓΑΛΑ       χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 537      ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 539      ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# 698   ΦΡΕΣΚΟ ΓΑΛΑ       χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr
# 705      ΓΙΑΟΥΡΤΙ  χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.)
# ...

# %%
maximum = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης στραγγάτο 1kg (καφέ συσκ.) f/f'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

maximum2 = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average2 = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum2 = (temp[temp['normalized_product'] == 'χαραλαμπίδης - κρίστης πλήρες (κόκκινο) 2ltr'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
plt.suptitle('Βασικά Καταναλωτικά Αγαθά', color = 'C3', fontsize = 16)

maximum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[0])
maximum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[0])
axes[0].legend({'Γάλα','Γιαούρτι'}, frameon=True)
axes[0].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)


average.plot(color = 'g', marker='.', alpha=0.8, ax=axes[1])
average2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[1])
axes[1].legend('', frameon=False)
axes[1].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Χαραλαμπίδης', color = 'C0', labelpad = 20, fontsize = 12)

minimum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[2])
minimum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[2])
axes[2].legend('', frameon=False)
axes[2].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Αγγουράκια

# %%
temp = basic[(basic['normalized_product'] == 'αγγουράκια χωραφιού (kg)')|(basic['normalized_product'] == 'αγγουράκια θερμοκηπίου (kg)')]
temp
# Out:
#        type                      product           normalized_product  \
# 127   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 128   ΧΟΡΤΑ     αγγουράκια χωραφιού (kg)     αγγουράκια χωραφιού (kg)
# 295   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 296   ΧΟΡΤΑ     αγγουράκια χωραφιού (kg)     αγγουράκια χωραφιού (kg)
# 463   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 464   ΧΟΡΤΑ     αγγουράκια χωραφιού (kg)     αγγουράκια χωραφιού (kg)
# 630   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 631   ΧΟΡΤΑ     αγγουράκια χωραφιού (kg)     αγγουράκια χωραφιού (kg)
# 798   ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 799   ΧΟΡΤΑ     αγγουράκια χωραφιού (kg)     αγγουράκια χωραφιού (kg)
# 1038  ΧΟΡΤΑ  αγγουράκια θερμοκηπίου (kg)  αγγουράκια θερμοκηπίου (kg)
# 1039  ΧΟΡΤΑ     αγγουράκια χωραφιού (kg)     αγγουράκια χωραφιού (kg)
# ...

# %%
maximum = (temp[temp['normalized_product'] == 'αγγουράκια θερμοκηπίου (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average = (temp[temp['normalized_product'] == 'αγγουράκια θερμοκηπίου (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum = (temp[temp['normalized_product'] == 'αγγουράκια θερμοκηπίου (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

maximum2 = (temp[temp['normalized_product'] == 'αγγουράκια χωραφιού (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average2 = (temp[temp['normalized_product'] == 'αγγουράκια χωραφιού (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum2 = (temp[temp['normalized_product'] == 'αγγουράκια χωραφιού (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
plt.suptitle('Βασικά Καταναλωτικά Αγαθά', color = 'C3', fontsize = 16)

maximum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[0])
maximum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[0])
axes[0].legend({'Θερμοκηπίου','χωραφιού'}, frameon=True)
axes[0].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)


average.plot(color = 'g', marker='.', alpha=0.8, ax=axes[1])
average2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[1])
axes[1].legend('', frameon=False)
axes[1].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Αγγούρια', color = 'C0', labelpad = 20, fontsize = 12)

minimum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[2])
minimum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[2])
axes[2].legend('', frameon=False)
axes[2].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# #### Ντομάτες - Πατάτες

# %%
temp = basic[(basic['normalized_product'] == 'ντομάτες α (kg)')|(basic['normalized_product'] == 'πατάτες φρέσκες (kg)')]
temp
# Out:
#        type               product    normalized_product  quantity   max   min  \
# 125   ΧΟΡΤΑ  πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.29  0.49
# 126   ΧΟΡΤΑ       ντομάτες α (kg)       ντομάτες α (kg)       1.0  3.40  2.15
# 293   ΧΟΡΤΑ  πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.29  0.69
# 294   ΧΟΡΤΑ       ντομάτες α (kg)       ντομάτες α (kg)       1.0  2.75  1.29
# 461   ΧΟΡΤΑ  πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.45  0.69
# 462   ΧΟΡΤΑ       ντομάτες α (kg)       ντομάτες α (kg)       1.0  1.45  0.40
# 628   ΧΟΡΤΑ  πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.59  0.99
# 629   ΧΟΡΤΑ       ντομάτες α (kg)       ντομάτες α (kg)       1.0  2.10  0.99
# 796   ΧΟΡΤΑ  πατάτες φρέσκες (kg)  πατάτες φρέσκες (kg)       1.0  1.39  0.79
# 797   ΧΟΡΤΑ       ντομάτες α (kg)       ντομάτες α (kg)       1.0  3.99  0.90
# 1040  ΧΟΡΤΑ       ντομάτες α (kg)       ντομάτες α (kg)       1.0  1.91  0.99
# ...

# %%
maximum = (temp[temp['normalized_product'] == 'ντομάτες α (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average = (temp[temp['normalized_product'] == 'ντομάτες α (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum = (temp[temp['normalized_product'] == 'ντομάτες α (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

maximum2 = (temp[temp['normalized_product'] == 'πατάτες φρέσκες (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'max':'mean'}))
average2 = (temp[temp['normalized_product'] == 'πατάτες φρέσκες (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'avg':'mean'}))
minimum2 = (temp[temp['normalized_product'] == 'πατάτες φρέσκες (kg)'].groupby(pd.Grouper(key='date',freq='M')).agg({'min':'mean'}))

# %%
fig, axes = plt.subplots(1, 3, figsize=(23,5))
plt.suptitle('Βασικά Καταναλωτικά Αγαθά', color = 'C3', fontsize = 16)

maximum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[0])
maximum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[0])
axes[0].legend({'Ντομάτες','Πατάτες'}, frameon=True)
axes[0].set_ylabel('Μέγιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[0].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)


average.plot(color = 'g', marker='.', alpha=0.8, ax=axes[1])
average2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[1])
axes[1].legend('', frameon=False)
axes[1].set_ylabel('Μέση Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[1].set_xlabel('Σύγκριση Τιμών: Ντομάτες - Πατάτες', color = 'C0', labelpad = 20, fontsize = 12)

minimum.plot(color = 'g', marker='.', alpha=0.8, ax=axes[2])
minimum2.plot(color = 'r', marker='.', alpha=0.8, ax=axes[2])
axes[2].legend('', frameon=False)
axes[2].set_ylabel('Ελάχιστη Τιμή', color = 'C0', labelpad = 20, fontsize = 12)
axes[2].set_xlabel('', color = 'C0', labelpad = 20, fontsize = 12)
# Out:
# Text(0.5, 0, '')
